# %%
import os
import re
import openai
import pandas as pd
from langchain.chat_models import ChatOpenAI
import matplotlib.pyplot as plt
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM
from unstructured.partition.pdf import partition_pdf
from unstructured.documents.elements import Table, NarrativeText, Text
from typing import List
from langchain.hub import pull
from langchain.chains import create_extraction_chain_pydantic
import json

# %%
def extract_pdf_elements_with_tables(pdf_path: str):
    elements = partition_pdf(filename=pdf_path, strategy="fast", infer_table_structure=True)
    return elements

def get_pdf_text_with_tables(pdf_path: str):
    elements = extract_pdf_elements_with_tables(pdf_path)
    extracted_content = []

    # Process the extracted elements
    for element in elements:
        if isinstance(element, Table):
            table_html = element.metadata.text_as_html
            extracted_content.append({"table": table_html})
        else:
            extracted_content.append({"text": element.text})

    return extracted_content

def extract_student_handbook_pdf():
    pdf_path = '/Users/bruce/Desktop/SCHOOL CHATBOT/data/student_handbook.pdf'
    extracted_data = get_pdf_text_with_tables(pdf_path)

    total_characters = 0
    for item in extracted_data:
        if 'text' in item:
            text_length = len(item['text'])
            total_characters += text_length
        if 'table' in item:
            table_length = len(item['table'])
            total_characters += table_length
    print(f"Total number of characters: {total_characters}")
    
    return extracted_data
    

def clean_text(text):
    text = re.sub(r'\d+\s*\|\s*P\s*a\s*g\s*e', '', text)
    text = re.sub(r'\n+', '\n', text) 
    text = re.sub(r'\s{2,}', ' ', text) 
    text = re.sub(r'•|\d+\.', '', text) 
    # Strip extra whitespace 
    text = text.strip() 
    
    return text

# Extract data
extracted_data = extract_student_handbook_pdf()

# Clean the text entries in the extracted data
cleaned_data = []
for item in extracted_data:
    if 'text' in item:
        cleaned_text = clean_text(item['text'])  # Clean the text
        cleaned_data.append({"text": cleaned_text})
    elif 'table' in item:
        cleaned_data.append({"table": item['table']})  # Keep the table as is

# Preview cleaned text and tables (first 5 entries)
#for i, item in enumerate(cleaned_data[:500]):
    #print(f"Entry {i+1}: {item}")
    
#print(cleaned_data[:200])

# Function to split text into paragraphs
def split_text_into_paragraphs(text_list):
    all_paragraphs = []
    
    # Iterate through each dictionary in the list
    for item in text_list:
        if 'text' in item:
            text = item['text']
            # Split the text into paragraphs using double newline
            paragraphs = text.split("\n\n")
            # Strip any extra whitespace and store non-empty paragraphs
            all_paragraphs.extend([para.strip() for para in paragraphs if para.strip()])
    
    return all_paragraphs

# Implementing clean paragraphs
paragraphs = split_text_into_paragraphs(cleaned_data)

for i,paragraph in enumerate(paragraphs[:50]):
      print(f"Paragraph {i+1}: {paragraph}")

# %%
len(paragraphs)
# Out:
# 1349

# %%
type(paragraphs)
# Out:
# list

# %%
openai_api_key = ""  
llm = ChatOpenAI(model="gpt-4-1106-preview", openai_api_key=openai_api_key)

# %%
obj = pull("wfh/proposal-indexing")

# %%
# Create a runnable that combines the prompt and the model
runnable = obj | llm

# %%
def get_propositions(text):
    # Use the runnable to extract propositions
    result = runnable.invoke({"input": text})
    
    # Extract the content part and remove the backticks and format indicators
    raw_content = result.content.strip().strip("```json").strip("```")
    
    # Parse the JSON string to a Python list
    try:
        propositions = json.loads(raw_content)
    except json.JSONDecodeError as e:
        print("Error decoding JSON:", e)
        propositions = []
    
    return propositions

# extracting propositions from The paragraphs
student_conduct_propositions = []
for i, paragraph in enumerate(paragraphs[694:]):
    proposition = get_propositions(paragraph)
    student_conduct_propositions.extend(proposition)
    print(f"Done with {694 + i}")
# Out:
# Done with 694
# Done with 695
# Done with 696
# Done with 697
# Done with 698
# Done with 699
# Done with 700
# Done with 701
# Done with 702
# Done with 703
# Done with 704
# Done with 705
# Done with 706
# Done with 707
# Done with 708
# Done with 709
# Done with 710
# Done with 711
# Done with 712
# Done with 713
# Done with 714
# Done with 715
# Done with 716
# Done with 717
# Done with 718
# Done with 719
# Done with 720
# Done with 721
# Done with 722
# Done with 723
# Done with 724
# Done with 725
# Done with 726
# Done with 727
# Done with 728
# Done with 729
# Done with 730
# Done with 731
# Done with 732
# Done with 733
# Done with 734
# Done with 735
# Done with 736
# Done with 737
# Done with 738
# Done with 739
# Done with 740
# Done with 741
# Done with 742
# Done with 743
# Done with 744
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Done with 745
# Done with 746
# Done with 747
# Done with 748
# Done with 749
# Done with 750
# Done with 751
# Done with 752
# Done with 753
# Done with 754
# Done with 755
# Done with 756
# Done with 757
# Done with 758
# Done with 759
# Done with 760
# Done with 761
# Done with 762
# Done with 763
# Done with 764
# Done with 765
# Done with 766
# Done with 767
# Done with 768
# Done with 769
# Done with 770
# Done with 771
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Done with 772
# Done with 773
# Done with 774
# Done with 775
# Done with 776
# Done with 777
# Done with 778
# Done with 779
# Done with 780
# Done with 781
# Done with 782
# Done with 783
# Done with 784
# Done with 785
# Done with 786
# Done with 787
# Done with 788
# Done with 789
# Done with 790
# Done with 791
# Done with 792
# Done with 793
# Done with 794
# Done with 795
# Done with 796
# Done with 797
# Done with 798
# Done with 799
# Done with 800
# Done with 801
# Done with 802
# Done with 803
# Done with 804
# Done with 805
# Done with 806
# Done with 807
# Done with 808
# Done with 809
# Done with 810
# Done with 811
# Done with 812
# Done with 813
# Done with 814
# Done with 815
# Done with 816
# Done with 817
# Done with 818
# Done with 819
# Done with 820
# Done with 821
# Done with 822
# Done with 823
# Done with 824
# Done with 825
# Done with 826
# Done with 827
# Done with 828
# Done with 829
# Done with 830
# Done with 831
# Done with 832
# Done with 833
# Done with 834
# Done with 835
# Done with 836
# Done with 837
# Done with 838
# Done with 839
# Done with 840
# Done with 841
# Done with 842
# Done with 843
# Done with 844
# Done with 845
# Done with 846
# Done with 847
# Done with 848
# Done with 849
# Done with 850
# Done with 851
# Done with 852
# Done with 853
# Done with 854
# Done with 855
# Done with 856
# Done with 857
# Done with 858
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Done with 859
# Done with 860
# Done with 861
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Done with 862
# Done with 863
# Done with 864
# Done with 865
# Done with 866
# Done with 867
# Done with 868
# Done with 869
# Done with 870
# Done with 871
# Done with 872
# Done with 873
# Done with 874
# Done with 875
# Done with 876
# Done with 877
# Done with 878
# Done with 879
# Done with 880
# Done with 881
# Done with 882
# Done with 883
# Done with 884
# Done with 885
# Done with 886
# Done with 887
# Done with 888
# Done with 889
# Done with 890
# Done with 891
# Done with 892
# Done with 893
# Done with 894
# Done with 895
# Done with 896
# Done with 897
# Done with 898
# Done with 899
# Done with 900
# Done with 901
# Done with 902
# Done with 903
# Done with 904
# Done with 905
# Done with 906
# Done with 907
# Done with 908
# Done with 909
# Done with 910
# Done with 911
# Done with 912
# Done with 913
# Done with 914
# Done with 915
# Done with 916
# Done with 917
# Done with 918
# Done with 919
# Done with 920
# Done with 921
# Done with 922
# Done with 923
# Done with 924
# Done with 925
# Done with 926
# Done with 927
# Done with 928
# Done with 929
# Done with 930
# Done with 931
# Done with 932
# Done with 933
# Done with 934
# Done with 935
# Done with 936
# Done with 937
# Done with 938
# Done with 939
# Done with 940
# Done with 941
# Done with 942
# Done with 943
# Done with 944
# Done with 945
# Done with 946
# Done with 947
# Done with 948
# Done with 949
# Done with 950
# Done with 951
# Done with 952
# Done with 953
# Done with 954
# Done with 955
# Done with 956
# Done with 957
# Done with 958
# Done with 959
# Done with 960
# Done with 961
# Done with 962
# Done with 963
# Done with 964
# Done with 965
# Done with 966
# Done with 967
# Done with 968
# Done with 969
# Done with 970
# Done with 971
# Done with 972
# Done with 973
# Done with 974
# Done with 975
# Done with 976
# Done with 977
# Done with 978
# Done with 979
# Done with 980
# Done with 981
# Done with 982
# Done with 983
# Done with 984
# Done with 985
# Done with 986
# Done with 987
# Done with 988
# Done with 989
# Done with 990
# Done with 991
# Done with 992
# Done with 993
# Done with 994
# Done with 995
# Done with 996
# Done with 997
# Done with 998
# Done with 999
# Done with 1000
# Done with 1001
# Done with 1002
# Done with 1003
# Done with 1004
# Done with 1005
# Done with 1006
# Done with 1007
# Done with 1008
# Done with 1009
# Done with 1010
# Done with 1011
# Done with 1012
# Done with 1013
# Done with 1014
# Done with 1015
# Done with 1016
# Done with 1017
# Done with 1018
# Done with 1019
# Done with 1020
# Done with 1021
# Done with 1022
# Done with 1023
# Done with 1024
# Done with 1025
# Done with 1026
# Done with 1027
# Done with 1028
# Done with 1029
# Done with 1030
# Done with 1031
# Done with 1032
# Done with 1033
# Done with 1034
# Done with 1035
# Done with 1036
# Done with 1037
# Done with 1038
# Done with 1039
# Done with 1040
# Done with 1041
# Done with 1042
# Done with 1043
# Done with 1044
# Done with 1045
# Done with 1046
# Done with 1047
# Done with 1048
# Done with 1049
# Done with 1050
# Done with 1051
# Done with 1052
# Done with 1053
# Done with 1054
# Done with 1055
# Done with 1056
# Done with 1057
# Done with 1058
# Done with 1059
# Done with 1060
# Done with 1061
# Done with 1062
# Done with 1063
# Done with 1064
# Done with 1065
# Done with 1066
# Done with 1067
# Done with 1068
# Done with 1069
# Done with 1070
# Done with 1071
# Done with 1072
# Done with 1073
# Done with 1074
# Done with 1075
# Done with 1076
# Done with 1077
# Done with 1078
# Done with 1079
# Done with 1080
# Done with 1081
# Done with 1082
# Done with 1083
# Done with 1084
# Done with 1085
# Done with 1086
# Done with 1087
# Done with 1088
# Done with 1089
# Done with 1090
# Done with 1091
# Done with 1092
# Done with 1093
# Done with 1094
# Done with 1095
# Done with 1096
# Done with 1097
# Done with 1098
# Done with 1099
# Done with 1100
# Done with 1101
# Done with 1102
# Done with 1103
# Done with 1104
# Done with 1105
# Done with 1106
# Done with 1107
# Done with 1108
# Done with 1109
# Done with 1110
# Done with 1111
# Done with 1112
# Done with 1113
# Done with 1114
# Done with 1115
# Done with 1116
# Done with 1117
# Done with 1118
# Done with 1119
# Done with 1120
# Done with 1121
# Done with 1122
# Done with 1123
# Done with 1124
# Done with 1125
# Done with 1126
# Done with 1127
# Done with 1128
# Done with 1129
# Done with 1130
# Done with 1131
# Done with 1132
# Done with 1133
# Done with 1134
# Done with 1135
# Done with 1136
# Done with 1137
# Done with 1138
# Done with 1139
# Done with 1140
# Done with 1141
# Done with 1142
# Done with 1143
# Done with 1144
# Done with 1145
# Done with 1146
# Done with 1147
# Done with 1148
# Done with 1149
# Done with 1150
# Done with 1151
# Done with 1152
# Done with 1153
# Done with 1154
# Done with 1155
# Done with 1156
# Done with 1157
# Done with 1158
# Done with 1159
# Done with 1160
# Done with 1161
# Done with 1162
# Done with 1163
# Done with 1164
# Done with 1165
# Done with 1166
# Done with 1167
# Done with 1168
# Done with 1169
# Done with 1170
# Done with 1171
# Done with 1172
# Done with 1173
# Done with 1174
# Done with 1175
# Done with 1176
# Done with 1177
# Done with 1178
# Done with 1179
# Done with 1180
# Done with 1181
# Error decoding JSON: Expecting ',' delimiter: line 5 column 3 (char 99)
# Done with 1182
# Done with 1183
# Done with 1184
# Done with 1185
# Done with 1186
# Done with 1187
# Done with 1188
# Done with 1189
# Done with 1190
# Done with 1191
# Done with 1192
# Done with 1193
# Done with 1194
# Done with 1195
# Done with 1196
# Done with 1197
# Done with 1198
# Done with 1199
# Done with 1200
# Done with 1201
# Done with 1202
# Done with 1203
# Done with 1204
# Done with 1205
# Done with 1206
# Done with 1207
# Done with 1208
# Done with 1209
# Done with 1210
# Done with 1211
# Done with 1212
# Done with 1213
# Done with 1214
# Done with 1215
# Done with 1216
# Done with 1217
# Done with 1218
# Done with 1219
# Done with 1220
# Done with 1221
# Done with 1222
# Done with 1223
# Done with 1224
# Done with 1225
# Done with 1226
# Done with 1227
# Done with 1228
# Done with 1229
# Done with 1230
# Done with 1231
# Done with 1232
# Done with 1233
# Done with 1234
# Done with 1235
# Done with 1236
# Done with 1237
# Done with 1238
# Done with 1239
# Done with 1240
# Done with 1241
# Done with 1242
# Done with 1243
# Done with 1244
# Error decoding JSON: Expecting value: line 1 column 1 (char 0)
# Done with 1245
# Done with 1246
# Done with 1247
# Done with 1248
# Done with 1249
# Done with 1250
# Done with 1251
# Done with 1252
# Done with 1253
# Done with 1254
# Done with 1255
# Done with 1256
# Done with 1257
# Done with 1258
# Done with 1259
# Done with 1260
# Done with 1261
# Done with 1262
# Done with 1263
# Done with 1264
# Done with 1265
# Done with 1266
# Done with 1267
# Done with 1268
# Done with 1269
# Done with 1270
# Done with 1271
# Done with 1272
# Done with 1273
# Done with 1274
# Done with 1275
# Done with 1276
# Done with 1277
# Done with 1278
# Done with 1279
# Done with 1280
# Done with 1281
# Done with 1282
# Done with 1283
# Done with 1284
# Done with 1285
# Done with 1286
# Done with 1287
# Done with 1288
# Done with 1289
# Done with 1290
# Done with 1291
# Done with 1292
# Done with 1293
# Done with 1294
# Done with 1295
# Done with 1296
# Done with 1297
# Done with 1298
# Done with 1299
# Done with 1300
# Done with 1301
# Done with 1302
# Done with 1303
# Done with 1304
# Error decoding JSON: Extra data: line 10 column 1 (char 941)
# Done with 1305
# Done with 1306
# Done with 1307
# Done with 1308
# Done with 1309
# Done with 1310
# Done with 1311
# Done with 1312
# Done with 1313
# Done with 1314
# Done with 1315
# Done with 1316
# Done with 1317
# Done with 1318
# Done with 1319
# Done with 1320
# Done with 1321
# Done with 1322
# Done with 1323
# Done with 1324
# Done with 1325
# Done with 1326
# Done with 1327
# Done with 1328
# Done with 1329
# Done with 1330
# Done with 1331
# Done with 1332
# Done with 1333
# Done with 1334
# Done with 1335
# Done with 1336
# Done with 1337
# Done with 1338
# Done with 1339
# Done with 1340
# Done with 1341
# Done with 1342
# Done with 1343
# Done with 1344
# Done with 1345
# Done with 1346
# Done with 1347
# Done with 1348

# %%
len(student_conduct_propositions)
# Out:
# 3720

# %%
with open('prep_batch.json', 'w') as file:
    json.dump(student_conduct_propositions, file)

# %%
with open('prep_batch.json', 'r') as file:
    loaded_list = json.load(file)

# %%
print(len(loaded_list))
# Out:
# 3090

# %%
from agentic_chunker import AgenticChunker

# %%
ac = AgenticChunker()

# %%
ac.add_propositions(student_conduct_propositions)
# Out:
# Adding: 'No organization/club shall intake members prior to meeting the college/university's requirements.'
# No chunks, creating a new one
# Created new chunk (cb0f2): College Organization Membership Rules
#
# Adding: 'No organization/club shall intake members prior to meeting the requirements of its national organization.'
# Chunk Found (cb0f2), adding to: College Organization Membership Rules
#
# Adding: 'No intake activity should be held without the presence of the advisor(s).'
# Chunk Found (cb0f2), adding to: Membership Intake Regulations for Educational Organizations
#
# Adding: 'HAZING in any form is prohibited.'
# Chunk Found (cb0f2), adding to: Educational Organization Membership Intake Rules & Advisor Requirements
#
# Adding: 'Physical abuse is prohibited.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Policies in Educational Organizations
#
# Adding: 'Mental abuse is prohibited.'
# No chunks found
# Created new chunk (806a0): Legal Status of Abuse
#
# Adding: 'Physical and mental abuse will not be tolerated.'
# Chunk Found (cb0f2), adding to: Regulations & Conduct in Educational Organization Membership
#
# Adding: 'A list of intended candidates must be filed with SEAL.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Rules in Organizations
#
# Adding: 'The list of intended candidates must be filed the following day after any informational meetings.'
# Chunk Found (cb0f2), adding to: Membership Intake Regulations & Prohibitions in Organizations & Clubs
#
# Adding: 'All students interested in joining a student organization must be authorized at Georgia State University (GSU).'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Guidelines in Organizations & Clubs
#
# Adding: 'All students interested in joining a student organization at Georgia State University (GSU) must take the Anti-Hazing certification course.'
# Chunk Found (cb0f2), adding to: Student Organization Policies & Anti-Hazing Regulations
#
# Adding: 'The Anti-Hazing certification course is sponsored by the Student Engagement and Leadership Center (SEAL).'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Rules in Student Organizations
#
# Adding: 'The Georgia State University (GSU) Anti-Hazing certification course is available on CANVAS.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Policies & Anti-Hazing Measures
#
# Adding: 'The Georgia State University (GSU) Anti-Hazing certification course is continuously available.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Hazing Prevention Regulations
#
# Adding: 'The following text pertains to expectations and requirements regarding membership intake programs for all recognized Social Non-Greek (NPHC) and Music Organizations at Georgia State University (GSU).'
# Chunk Found (cb0f2), adding to: Student Organization Membership & Anti-Hazing Policies at GSU
#
# Adding: 'All organizations at GSU are always required to follow the Membership Intake Program (MIP).'
# Chunk Found (cb0f2), adding to: University Membership Intake & Hazing Prevention Policies
#
# Adding: 'The Membership Intake Program (MIP) is developed and disseminated by the SEAL.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'The SEAL is associated with Georgia State University (GSU).'
# No chunks found
# Created new chunk (814e1): Georgia State University Affiliates
#
# Adding: 'All organizations at GSU are required to follow the Membership Intake Program (MIP) disseminated by their respective Regional/National Headquarters.'
# Chunk Found (cb0f2), adding to: University Membership Intake & Anti-Hazing Policies
#
# Adding: 'Intakes occur two times a year.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'One intake occurs in the fall.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Policies at GSU
#
# Adding: 'The fall intake occurs in the month of October.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Regulations at GSU
#
# Adding: 'Another intake occurs in the spring.'
# Chunk Found (cb0f2), adding to: University Organization Membership Policies & Compliance at GSU
#
# Adding: 'The spring intake occurs in the month of February.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'Any changes to the intake schedule must first be cleared with SEAL.'
# Chunk Found (cb0f2), adding to: University Student Membership & Compliance Policies
#
# Adding: 'All chapters are responsible for educating undergraduates.'
# No chunks found
# Created new chunk (aeb3d): University Chapter Responsibilities
#
# Adding: 'Chapters must educate undergraduates regarding all MIP policies.'
# Chunk Found (aeb3d), adding to: University Chapter Responsibilities
#
# Adding: 'Procedures are mentioned.'
# No chunks found
# Created new chunk (6bc03): Procedures & Methods
#
# Adding: 'Appropriate activities are mentioned.'
# No chunks found
# Created new chunk (8ed83): Activity Recommendations
#
# Adding: 'A chapter must complete certain tasks when it initiates the MIP.'
# Chunk Found (aeb3d), adding to: Educational Responsibilities of University Chapters
#
# Adding: 'The tasks must be completed with SEAL.'
# No chunks found
# Created new chunk (2f5fc): Task Requirements
#
# Adding: 'A person must pick up a Membership Intake Process (MIP) packet from the Student Engagement and Leadership (SEAL).'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'A person must complete all required forms for Membership Intake Process (MIP).'
# Chunk Found (cb0f2), adding to: GSU Membership Intake & Anti-Hazing Policies
#
# Adding: 'A person must submit all completed forms for Membership Intake Process (MIP) to the Student Engagement and Leadership (SEAL).'
# Chunk Found (cb0f2), adding to: Student Organization Intake Regulations & Anti-Hazing at GSU
#
# Adding: 'A person must notify the Student Engagement and Leadership (SEAL) of any subsequent changes in the status of Membership Intake Process (MIP) candidate(s).'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at Georgia State University
#
# Adding: 'A person must notify the Student Engagement and Leadership (SEAL) of any results of the Membership Intake Process (MIP) candidate(s) status.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Membership & Anti-Hazing Guidelines
#
# Adding: 'If the organization is nationally affiliated, the chapter must provide verification.'
# Chunk Found (814e1), adding to: Georgia State University Affiliates
#
# Adding: 'The verification must confirm that approval from the Regional/National Headquarters has been granted.'
# Chunk Found (cb0f2), adding to: University Student Organization Intake & Compliance Policies
#
# Adding: 'The approval must be for conducting membership intake.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Membership Intake & Anti-Hazing Regulations
#
# Adding: 'Each chapter must submit a calendar of events for intake activities.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Procedures & Anti-Hazing Policies
#
# Adding: 'Each chapter must submit an Intent to Conduct Form.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Membership & Compliance Guidelines
#
# Adding: 'Each chapter must submit the Hazing Compliance Form.'
# Chunk Found (cb0f2), adding to: University Student Organization Intake & Anti-Hazing Policies
#
# Adding: 'The submission of the calendar of events, Intent to Conduct Form, and the Hazing Compliance Form must occur at the initial notification of SEAL's intent to conduct membership intake.'
# Chunk Found (cb0f2), adding to: Membership Intake Procedures & Anti-Hazing Education at GSU
#
# Adding: 'The calendar of events must include a timetable of all intake activities.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'The timetable must specify places of the intake activities.'
# Chunk Found (cb0f2), adding to: Membership Intake Procedures & Hazing Prevention at Georgia State University
#
# Adding: 'The timetable must specify dates of the intake activities.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'The timetable must specify times of the intake activities.'
# Chunk Found (cb0f2), adding to: University Membership Intake & Compliance Procedures
#
# Adding: 'Activities to be included on the calendar are unspecified and the sentence is incomplete.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'All intake activities must end before the start of homecoming in the fall semester.'
# Chunk Found (cb0f2), adding to: Membership Intake & Compliance Procedures for GSU Student Organizations
#
# Adding: 'All intake activities must end before the start of spring fest activities in the spring semester.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake, Anti-Hazing & Event Scheduling Regulations
#
# Adding: 'Intake activities must pause during mid-term exams.'
# Chunk Found (cb0f2), adding to: University Membership Intake & Compliance Guidelines
#
# Adding: 'The selection date(s) for new members must be established.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'The start date of the new member's official process/education must be established.'
# Chunk Found (aeb3d), adding to: University Chapter Duties & MIP Education
#
# Adding: 'The end date of the new member's official process/education must be established.'
# Chunk Found (aeb3d), adding to: University Chapter Initiation & Education Procedures
#
# Adding: 'All activities in the new member's official process/education must be included between the start and end dates.'
# Chunk Found (aeb3d), adding to: Chapter Education & Initiation Timelines
#
# Adding: 'Meetings can be informational.'
# No chunks found
# Created new chunk (bdaff): Meeting Purposes & Characteristics
#
# Adding: 'Meetings can be held to generate or address interest.'
# Chunk Found (bdaff), adding to: Meeting Purposes & Characteristics
#
# Adding: 'An initiation date exists.'
# Chunk Found (aeb3d), adding to: MIP Education Guidelines & Scheduling
#
# Adding: 'New members are presented.'
# Chunk Found (cb0f2), adding to: Membership Intake Guidelines & Compliance at Georgia State University
#
# Adding: 'The presentation of new members may include a probate show.'
# Chunk Found (aeb3d), adding to: Educational Procedures & Timelines in MIP
#
# Adding: 'A copy of the University Facility Use Form must be submitted if the presentation includes a probate show.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'A copy of the protocol must be submitted if the presentation includes a probate show.'
# Chunk Found (cb0f2), adding to: Membership Intake Process Guidelines at Georgia State University
#
# Adding: 'A copy of the Activity Clearance form must be submitted if the presentation includes a probate show.'
# Chunk Found (aeb3d), adding to: Fraternity Initiation & Education Guidelines
#
# Adding: 'The University Facility Use Form is required to proceed with the activity of presenting new members with a probate show.'
# Chunk Found (aeb3d), adding to: Fraternity Membership Induction Process (MIP) Guidelines
#
# Adding: 'The protocol is required to proceed with the activity of presenting new members with a probate show.'
# Chunk Found (aeb3d), adding to: Educational Obligations & Initiation Procedures in Organizations
#
# Adding: 'The Activity Clearance form is required to proceed with the activity of presenting new members with a probate show.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Membership Induction Processes
#
# Adding: 'The required documents must be submitted two weeks in advance of the activity involving the presentation of new members with a probate show.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority New Member Education and Event Protocols
#
# Adding: 'The presentation of new members may include a probate show.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Initiation Procedures and Documentation Requirements
#
# Adding: 'If the presentation of new members does not include a probate show, then a specified event or consequence occurs.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority New Member Education and Initiation Protocols
#
# Adding: 'The method used should be included on the Activity Clearance Form.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Initiation and Event Planning Procedures
#
# Adding: 'The method used should be discussed before approval will be granted.'
# Chunk Found (6bc03), adding to: Procedures & Methods
#
# Adding: 'The Intent to Conduct Membership Intake Form must contain the original signature of the chapter president.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'The Intent to Conduct Membership Intake Form must contain the original signature of the primary chapter advisor.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Prevention Guidelines at GSU
#
# Adding: 'All organizations that are not NPHC authorized will follow the guidance found in the form.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Compliance Procedures
#
# Adding: 'All organizations that are not GSU authorized Music/Band organizations will follow the guidance found in the form.'
# Chunk Found (814e1), adding to: Organizational Requirements & Affiliations at GSU
#
# Adding: 'The guidance for the organizations is found in the form located at the link life/clubs/docs/Form%20Hazing%20form%20simple%20mem%20intake.pdf.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at Georgia State University
#
# Adding: 'New members must be cleared by the SEAL office.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Procedures & Hazing Prevention at GSU
#
# Adding: 'The presentation of new members takes place after they have been cleared by the SEAL office.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority New Member Education and Event Protocols
#
# Adding: 'The presentation of new members will be placed within the calendar set forth by the SEAL.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines at GSU
#
# Adding: 'The presentation of new members will be scheduled at the discretion of the SEAL.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Membership & Anti-Hazing Policies
#
# Adding: 'Vulgarity will not be tolerated.'
# Chunk Found (cb0f2), adding to: University Membership Intake & Compliance Regulations
#
# Adding: 'Profanity will not be tolerated.'
# No chunks found
# Created new chunk (4baa3): Language & Behavior Policies
#
# Adding: 'No attire that is explicit or revealing will be permitted.'
# Chunk Found (4baa3), adding to: Language & Behavior Policies
#
# Adding: 'No alcoholic substances will be permitted.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Policies & Anti-Hazing Measures
#
# Adding: 'No drugs will be permitted.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Guidelines for GSU Student Organizations
#
# Adding: 'In the event of aggressive behavior during a presentation, those identified will be referred to the Office of Student Conduct.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Policies & Anti-Hazing Regulations
#
# Adding: 'The Office of Student Conduct will determine penalties for inappropriate behavior.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Guidelines at GSU
#
# Adding: 'The University Police Department will determine if the presentation continues.'
# No chunks found
# Created new chunk (b2caf): Campus Security Management
#
# Adding: 'Disruptions by other organizations will not be tolerated.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Conduct Policies
#
# Adding: 'Walking through the presenters' show is included in the disruptions that will not be tolerated.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Initiation Procedures and Documentation
#
# Adding: 'Talking over the presentation organization is included in the disruptions that will not be tolerated.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Guidelines at Georgia State University
#
# Adding: 'Heckling is a form of talking over the presentation organization.'
# No chunks found
# Created new chunk (f8a9c): Heckling Effects
#
# Adding: 'Making rude remarks is a form of talking over the presentation organization.'
# Chunk Found (f8a9c), adding to: Heckling Effects
#
# Adding: 'The duration of the probate show should be no longer than three hours.'
# Chunk Found (aeb3d), adding to: Induction Processes & Event Protocols for New Members
#
# Adding: 'Following the probate show, members must vacate the area within 30 minutes.'
# Chunk Found (aeb3d), adding to: Education, Initiation & Event Guidelines for New Members
#
# Adding: 'Vacating the area within 30 minutes will help with crowd disbursement.'
# Chunk Found (b2caf), adding to: Campus Security Management
#
# Adding: 'The presenting organization will be responsible for ensuring the site is left in its original state.'
# Chunk Found (aeb3d), adding to: Fraternity/Sorority Membership Onboarding & Event Protocols
#
# Adding: 'The presenting organization's responsibility occurs after the use of the site.'
# Chunk Found (aeb3d), adding to: Fraternity/Sorority Initiation & Event Planning Procedures
#
# Adding: 'All organizations are responsible for visitors who are members of those organizations.'
# Chunk Found (814e1), adding to: GSU Organizational Regulations & Verification
#
# Adding: 'Intake activities must take place on the campus.'
# Chunk Found (cb0f2), adding to: Georgia State University Student Organization Intake Policies & Procedures
#
# Adding: 'An updated membership roster must be turned in to SEAL.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Intake Guidelines at Georgia State University
#
# Adding: 'The updated membership roster must be turned in immediately after the conclusion of the intake process.'
# Chunk Found (cb0f2), adding to: Georgia State University Student Organization Intake & Conduct Policies
#
# Adding: 'The intake process concludes with induction.'
# Chunk Found (aeb3d), adding to: Fraternity/Sorority Member Education & Event Protocols
#
# Adding: 'The updated membership roster must be turned in within two days of induction.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Intake Guidelines at GSU
#
# Adding: 'Each Greek letter organization may conduct one Membership Intake Process (MIP) in the spring.'
# Chunk Found (cb0f2), adding to: GSU Student Membership Intake & Conduct Policies
#
# Adding: 'Each Greek letter organization may conduct one Membership Intake Process (MIP) in the fall.'
# Chunk Found (cb0f2), adding to: GSU Membership Intake Guidelines & Anti-Hazing Policies
#
# Adding: 'If the proper paperwork is not submitted within the time designated by SEAL, intake activity will be'
# Chunk Found (cb0f2), adding to: University Membership Intake & Conduct Regulations
#
# Adding: 'An organization's progress in their process does not affect the denial or suspension of something.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Guidelines & Conduct Policies
#
# Adding: 'All candidates and members must be excluded from membership activities.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at Georgia State University
#
# Adding: 'Candidates and members must complete the Anti-hazing course on CANVAS to avoid exclusion from membership activities.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Guidelines at GSU
#
# Adding: 'There is an Anti-hazing course available on CANVAS.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at GSU
#
# Adding: 'To complete the CANVAS Anti-hazing course, one must click a link.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Guidelines at GSU
#
# Adding: 'The link to complete the CANVAS Anti-hazing course is https://grambling.instructure.com/courses/11165.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Policies
#
# Adding: 'Violations of the intake process may result in probation for the involved individuals or organization.'
# Chunk Found (cb0f2), adding to: University Membership Intake Regulations & Anti-Hazing Guidelines
#
# Adding: 'Violations of the intake process may result in immediate interim suspension for the involved individuals or organization until the investigation is complete.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Policies
#
# Adding: 'Violations of the intake process may result in expulsion for the involved individuals or organization if the investigation confirms that hazing was involved in the activities of the organization.'
# Chunk Found (cb0f2), adding to: University Membership Intake Regulations & Anti-Hazing Guidelines
#
# Adding: 'The decision whether the chapter will be placed on probation or receive automatic suspension is based upon the infractions.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Conduct Policies at Georgia State University
#
# Adding: 'The decision about probation or suspension is at the discretion of the SEAL Director.'
# Chunk Found (cb0f2), adding to: Membership Intake Regulations & Anti-Hazing Policies at GSU
#
# Adding: 'The decision about probation or suspension is at the discretion of the Vice President for Student Affairs.'
# Chunk Found (cb0f2), adding to: GSU Membership Intake & Anti-Hazing Guidelines
#
# Adding: 'The decision about probation or suspension is at the discretion of another University governing body.'
# Chunk Found (cb0f2), adding to: University Membership Intake Regulations & Anti-Hazing Policies
#
# Adding: 'The Office of Student Conduct is a University governing body.'
# No chunks found
# Created new chunk (bf020): University Governance
#
# Adding: 'The GSU Police Department is a University governing body.'
# No chunks found
# Created new chunk (88c23): GSU Police Department Functions
#
# Adding: 'The adjudication of cases may be referred to the Office of Student Conduct.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Guidelines at GSU
#
# Adding: 'The referral of cases to the Office of Student Conduct is at the discretion of SEAL.'
# Chunk Found (cb0f2), adding to: Membership Intake & Compliance Procedures at Georgia State University
#
# Adding: 'The referral of cases to the Office of Student Conduct is at the discretion of the Vice President for student affairs or its surrogate.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'Investigation may be of hazing violations.'
# Chunk Found (cb0f2), adding to: Membership Intake, Anti-Hazing, and Conduct Guidelines for GSU Student Organizations
#
# Adding: 'The input contains the word 'to'.'
# No chunks found
# Created new chunk (6e629): Prepositions Usage
#
# Adding: 'Violations are not limited to the following list.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Policies at GSU
#
# Adding: 'Violations include certain actions or behaviors that are not specified here.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Regulations at GSU
#
# Adding: 'There is an intentional submission of improper paperwork.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Compliance Guidelines at GSU
#
# Adding: 'Improper paperwork includes changing of dates on forms.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at Georgia State University
#
# Adding: 'Improper paperwork includes falsifying original signatures.'
# Chunk Found (cb0f2), adding to: Student Organization Intake, Anti-Hazing, and Compliance at GSU
#
# Adding: 'Improper paperwork includes submission of incomplete paperwork.'
# Chunk Found (2f5fc), adding to: Task Requirements
#
# Adding: 'Holding membership intake without conforming to the intake guidelines set forth in the handbook is an action.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Policies at GSU
#
# Adding: 'There are intake guidelines set forth in the handbook.'
# Chunk Found (cb0f2), adding to: Student Organization Intake, Conduct, and Anti-Hazing Regulations at GSU
#
# Adding: 'All students must comply with the GSU Student Code of Conduct.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Guidelines for GSU Organizations
#
# Adding: 'All students must comply with the requirements of the GSU Student Code of Conduct.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Anti-Hazing Policies at GSU
#
# Adding: 'All students participating in membership intake must comply with the intake guidelines set forth in the handbook.'
# Chunk Found (cb0f2), adding to: Membership Intake, Anti-Hazing, and Conduct Standards for GSU Student Organizations
#
# Adding: 'All incidents of hazing must be reported first to SEAL immediately.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Regulations for GSU Student Organizations
#
# Adding: 'All incidents of hazing must be reported to SEAL before any organization outside the University is notified.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Policies & Hazing Prevention at GSU
#
# Adding: 'This includes the national office of the organization.'
# Chunk Found (814e1), adding to: GSU Organizational Guidelines & Affiliations
#
# Adding: 'This includes the regional office of the organization.'
# No chunks found
# Created new chunk (6648b): Organization Locations & Facilities
#
# Adding: 'This includes the district office of the organization.'
# Chunk Found (6648b), adding to: Organization Locations & Facilities
#
# Adding: 'Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by advisors.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines at GSU
#
# Adding: 'Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by other University personnel.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Procedures & Compliance at GSU
#
# Adding: 'Failure by any student to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines at GSU
#
# Adding: 'Failure by any advisor to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.'
# Chunk Found (aeb3d), adding to: Fraternity/Sorority Initiation & Event Management Procedures
#
# Adding: 'All incidents of hazing must be reported first to SEAL immediately.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Procedures & Conduct at GSU
#
# Adding: 'All incidents of hazing must be reported to SEAL before any organization outside the University is notified.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines at GSU
#
# Adding: 'This includes the national office of the organization.'
# Chunk Found (6648b), adding to: Organization Offices & Facilities
#
# Adding: 'This includes the regional office of the organization.'
# Chunk Found (6648b), adding to: Organization Office Hierarchies
#
# Adding: 'This includes the district office of the organization.'
# Chunk Found (6648b), adding to: Organizational Structures & Locations
#
# Adding: 'Disregard of guidelines for any activity related to intake is an action.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Conduct Policies at GSU
#
# Adding: 'Any activity related to intake conducted in defiance of previous warnings by advisors is an action.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Regulations at GSU
#
# Adding: 'Any activity related to intake conducted in defiance of previous warnings by other University personnel is an action.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Procedures & Conduct Policies at GSU
#
# Adding: 'Failure to adhere to Presentation of New Membership Guidelines by any student will be subject to disciplinary sanction.'
# Chunk Found (aeb3d), adding to: Educational & Event Guidelines for New Member Induction
#
# Adding: 'Failure to adhere to Presentation of New Membership Guidelines by any advisor will be subject to disciplinary sanction.'
# Chunk Found (aeb3d), adding to: New Member Induction & Presentation Procedures
#
# Adding: 'Intake activities must not begin without the knowledge of the SEAL Director.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines for GSU Organizations
#
# Adding: 'Intake activities must not begin without the signed approval of the SEAL Director.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Standards for GSU Student Organizations
#
# Adding: 'The chapter must adhere to the intake guidelines.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Guidelines & Anti-Hazing Policies
#
# Adding: 'If intake activities begin without the knowledge of the SEAL Director, the intake activities will cease immediately.'
# Chunk Found (cb0f2), adding to: Membership Intake & Conduct Rules for GSU Student Organizations
#
# Adding: 'If intake activities begin without the signed approval of the SEAL Director, the intake activities will cease immediately.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Guidelines & Anti-Hazing Policies
#
# Adding: 'If the chapter has not adhered to the intake guidelines, the intake activities will cease immediately.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Prevention at Georgia State University
#
# Adding: 'The chapter may be placed on suspension if the intake activities begin without the knowledge of the SEAL Director.'
# Chunk Found (cb0f2), adding to: GSU Membership Intake Guidelines & Anti-Hazing Policies
#
# Adding: 'The chapter may be placed on suspension if the intake activities begin without the signed approval of the SEAL Director.'
# Chunk Found (cb0f2), adding to: Student Organization Intake & Hazing Prevention at GSU
#
# Adding: 'The chapter may be placed on suspension if the chapter has not adhered to the intake guidelines.'
# Chunk Found (cb0f2), adding to: Membership Intake & Anti-Hazing Guidelines for GSU Organizations
#
# Adding: 'Sanctions will be administered at the discretion of the SEAL Director.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Procedures & Hazing Policy at GSU
#
# Adding: 'Proper planning is considered the key to any successful event.'
# Chunk Found (aeb3d), adding to: Educational Guidelines & Event Protocols for New Member Induction
#
# Adding: 'The Department of Student Activities staff are available to assist student organizations as needed.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Regulations for GSU Student Organizations
#
# Adding: 'Events taking place within the Favrot Student Union are supported by the student union staff.'
# Chunk Found (aeb3d), adding to: New Member Induction & Probate Show Procedures
#
# Adding: 'Grambling State University is host to organizations affiliated with the National Pan Hellenic Council.'
# Chunk Found (814e1), adding to: University Organization Policies & Affiliations
#
# Adding: 'Grambling State University is host to organizations affiliated with the national music and band sororities/fraternities.'
# Chunk Found (814e1), adding to: University Organization Guidelines & Affiliations
#
# Adding: 'The organizations are affiliated through the music department.'
# Chunk Found (814e1), adding to: University Organization Policies & Affiliations
#
# Adding: 'The organizations have requirements and conditions to fulfill through their national governing bodies.'
# Chunk Found (814e1), adding to: University-Affiliated Organizations & Regulations
#
# Adding: 'Grambling State University grants recognition to student organizations.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Guidelines & Anti-Hazing Policies
#
# Adding: 'Grambling State University grants recognition with the understanding.'
# No chunks found
# Created new chunk (b4d92): University Awards & Honors
#
# Adding: 'The organization will comply with the mission of the University.'
# Chunk Found (814e1), adding to: University Affiliations & Organizational Guidelines
#
# Adding: 'The organization will comply with the mission of its national body.'
# Chunk Found (814e1), adding to: University-Affiliated Organizations & Regulations
#
# Adding: 'The organization is committed to improving the quality of student life.'
# Chunk Found (cb0f2), adding to: University Student Organization Membership & Conduct Regulations
#
# Adding: 'The organization aims to build strong community relationships.'
# No chunks found
# Created new chunk (95eee): Community Engagement Goals
#
# Adding: 'Social relationships are connections between individuals in a society.'
# No chunks found
# Created new chunk (7f240): Social Relationships Dynamics
#
# Adding: 'Social relationships involve interactions among individuals.'
# Chunk Found (7f240), adding to: Social Relationships Dynamics
#
# Adding: 'Social relationships can be of different types such as friendships, familial bonds, and professional associations.'
# Chunk Found (7f240), adding to: Social Relationships & Interactions
#
# Adding: 'The organization provides service to the community.'
# Chunk Found (95eee), adding to: Community Engagement Goals
#
# Adding: 'The organization provides service to the school.'
# Chunk Found (95eee), adding to: Community Service & Engagement Initiatives
#
# Adding: 'The organization is committed to scholastic achievement.'
# No chunks found
# Created new chunk (cf74d): Organizational Values in Education
#
# Adding: 'The organization is committed to leadership development.'
# No chunks found
# Created new chunk (e8f3c): Organizational Commitments & Initiatives
#
# Adding: 'A list of organizations exists.'
# No chunks found
# Created new chunk (24974): Organizations & Details
#
# Adding: 'The organizations on the list must follow the University guidelines.'
# Chunk Found (814e1), adding to: University Affiliations & Compliance Requirements
#
# Adding: 'NPHC stands for National Pan-Hellenic Council.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Initiation and Presentation Guidelines
#
# Adding: 'NPHC includes fraternities.'
# Chunk Found (aeb3d), adding to: Greek Life Membership Induction & Event Protocols
#
# Adding: 'NPHC includes sororities.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Induction Procedures and Event Guidelines
#
# Adding: 'Alpha Phi Alpha is a fraternity.'
# No chunks found
# Created new chunk (d0e0f): Greek Life Organizations
#
# Adding: 'Alpha Phi Alpha is part of NPHC.'
# Chunk Found (d0e0f), adding to: Greek Life Organizations
#
# Adding: 'Alpha Phi Alpha has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Fraternities & Affiliations
#
# Adding: 'Alpha Kappa Alpha is a sorority.'
# No chunks found
# Created new chunk (3ccd1): Greek Life Organizations
#
# Adding: 'Alpha Kappa Alpha is part of NPHC.'
# Chunk Found (3ccd1), adding to: Greek Life Organizations
#
# Adding: 'Alpha Kappa Alpha has the designation 'Inc.''
# Chunk Found (3ccd1), adding to: Sororities & Council Affiliations
#
# Adding: 'Iota Phi Theta is a fraternity.'
# Chunk Found (d0e0f), adding to: Alpha Phi Alpha Fraternity Details
#
# Adding: 'Iota Phi Theta is part of NPHC.'
# Chunk Found (3ccd1), adding to: Greek Letter Organizations & Affiliations
#
# Adding: 'Iota Phi Theta has the designation 'Inc.''
# Chunk Found (3ccd1), adding to: Greek Letter Organizations, Affiliations & Designations
#
# Adding: 'Delta Sigma Theta is a sorority.'
# Chunk Found (3ccd1), adding to: Greek Letter Organizations & NPHC Membership
#
# Adding: 'Delta Sigma Theta is part of NPHC.'
# Chunk Found (3ccd1), adding to: Greek Letter Organizations, NPHC Membership & Incorporation Status
#
# Adding: 'Delta Sigma Theta has the designation 'Inc.''
# Chunk Found (3ccd1), adding to: Greek Letter Organizations & NPHC Affiliations
#
# Adding: 'Kappa Alpha Psi is a fraternity.'
# Chunk Found (d0e0f), adding to: Fraternities: Affiliations & Designations
#
# Adding: 'Kappa Alpha Psi is part of NPHC.'
# Chunk Found (3ccd1), adding to: Sororities & Fraternities in NPHC
#
# Adding: 'Kappa Alpha Psi has the designation 'Inc.''
# Chunk Found (3ccd1), adding to: Greek Letter Organizations in NPHC
#
# Adding: 'Sigma Gamma Rho is a sorority.'
# Chunk Found (d0e0f), adding to: Fraternities & Greek Organizations
#
# Adding: 'Sigma Gamma Rho is part of NPHC.'
# Chunk Found (3ccd1), adding to: NPHC Greek Letter Organizations & Incorporation Status
#
# Adding: 'Sigma Gamma Rho has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Greek Letter Organizations & Designations
#
# Adding: 'Omega Psi Phi is a fraternity.'
# Chunk Found (d0e0f), adding to: Greek Letter Organizations in NPHC
#
# Adding: 'Omega Psi Phi is part of NPHC.'
# Chunk Found (d0e0f), adding to: NPHC Fraternities & Sororities
#
# Adding: 'Omega Psi Phi has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Greek Letter Organizations & Affiliations
#
# Adding: 'Zeta Phi Beta is a sorority.'
# Chunk Found (3ccd1), adding to: Greek Letter Organizations in NPHC
#
# Adding: 'Zeta Phi Beta is part of NPHC.'
# Chunk Found (d0e0f), adding to: Greek Letter Organizations, NPHC Membership & Designations
#
# Adding: 'Zeta Phi Beta has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Greek Letter Organizations & Affiliations
#
# Adding: 'Phi Beta Sigma is a fraternity.'
# Chunk Found (3ccd1), adding to: NPHC Sororities & Fraternities
#
# Adding: 'Phi Beta Sigma is part of NPHC.'
# Chunk Found (3ccd1), adding to: Greek Letter Organizations & NPHC Membership
#
# Adding: 'Phi Beta Sigma has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Greek Letter Organizations, Affiliations & Incorporation Status
#
# Adding: 'Phi Mu Alpha Sinfonia is a band/music organization.'
# Chunk Found (814e1), adding to: University-Affiliated Organizations & Governance
#
# Adding: 'Phi Mu Alpha Sinfonia is a fraternity.'
# Chunk Found (d0e0f), adding to: Greek Letter Organizations & NPHC Membership
#
# Adding: 'Phi Mu Alpha Sinfonia has the designation 'Inc.''
# Chunk Found (d0e0f), adding to: Greek Letter Organizations, Affiliations & Incorporation Status
#
# Adding: 'Sigma Alpha Iota is an international music fraternity.'
# Chunk Found (814e1), adding to: University Affiliations & Compliance Standards
#
# Adding: 'Kappa Kappa Psi is a fraternity.'
# Chunk Found (3ccd1), adding to: NPHC Greek Letter Organizations & Designations
#
# Adding: 'Tau Beta Sigma is an honorary band sorority.'
# Chunk Found (814e1), adding to: University Organizations: Regulations & Affiliations
#
# Adding: 'Students must be currently registered at GSU to participate in membership intake.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Prevention Policies at GSU
#
# Adding: 'Students must be registered for a minimum of 12 semester hours at GSU to participate in membership intake.'
# Chunk Found (cb0f2), adding to: University Organization Membership Guidelines & Compliance
#
# Adding: 'Students must have completed 30 hours at GSU before the semester within which they are establishing eligibility to participate in membership intake.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Prevention Policies at GSU
#
# Adding: 'Hours earned in a dual high school GSU undergraduate program can be used for qualifying hours earned.'
# No chunks found
# Created new chunk (8c38e): Dual Enrollment Credit Transfer Policies
#
# Adding: 'Students must meet certain criteria to participate in membership intake.'
# Chunk Found (cb0f2), adding to: Student Organization Intake Guidelines & Hazing Prevention at GSU
#
# Adding: 'A full-time GSU student is a student who has earned thirty (30) academic credit hours at GSU.'
# No chunks found
# Created new chunk (f8c83): Full-Time Student Criteria
#
# Adding: 'The academic credit hours earned at GSU by the full-time GSU student are non-remedial.'
# Chunk Found (f8c83), adding to: Full-Time Student Criteria
#
# Adding: 'A full-time GSU student is officially classified as a sophomore or above at the end of the previous spring semester.'
# Chunk Found (f8c83), adding to: Academic Credit Hours for Full-Time GSU Students
#
# Adding: 'Has a cumulative grade point average of at least 50.'
# Chunk Found (f8c83), adding to: Full-Time GSU Student Classification & Requirements
#
# Adding: 'Was enrolled full-time at GSU.'
# Chunk Found (f8c83), adding to: Academic Criteria for Full-Time GSU Students
#
# Adding: 'Completed the semester at GSU prior to intake.'
# Chunk Found (cb0f2), adding to: Membership Intake & Hazing Policy for GSU Student Organizations
#
# Adding: 'The entity is in good standing academically with the University.'
# Chunk Found (f8c83), adding to: Full-Time GSU Student Qualifications
#
# Adding: 'The entity has had no disciplinary sanctions at the University during the past two years.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake Guidelines & Anti-Hazing Regulations
#
# Adding: 'The Office of Student Engagement and Leadership officially cleared the policy.'
# Chunk Found (cb0f2), adding to: Student Organization Membership Intake & Hazing Policies at GSU
#
# Adding: 'Chapters are forbidden to send students to the registrar’s office.'
# Chunk Found (aeb3d), adding to: Greek Life Education, Initiation, and Event Protocols
#
# Adding: 'Chapters are forbidden to request transcripts for intake purposes.'
# Chunk Found (cb0f2), adding to: Membership Intake, Hazing Prevention, and Event Guidelines at GSU
#
# Adding: 'Transcripts can only be requested through the Office of Student Clubs and Organizations.'
# No chunks found
# Created new chunk (cf2fb): Transcript Request Procedures
#
# Adding: 'The purpose of requesting transcripts through the Office of Student Clubs and Organizations is for membership intake.'
# Chunk Found (cf2fb), adding to: Transcript Request Procedures
#
# Adding: 'All chapters must conduct membership intake.'
# Chunk Found (aeb3d), adding to: Fraternity & Sorority Membership Induction and Event Guidelines
#
# Adding: 'Membership intake must occur during the fall semester.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Compliance Procedures
#
# Adding: 'Alternatively, membership intake must occur during the spring semester.'
# Chunk Found (cb0f2), adding to: University Membership Intake & Hazing Policies
#
# Adding: 'Membership intake must occur during the time allotted for intake purposes.'
# Chunk Found (cb0f2), adding to: GSU Student Organization Intake & Anti-Hazing Regulations
#
# Adding: 'An intake calendar will be published.'
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[128], line 1
# ----> 1 ac.add_propositions(student_conduct_propositions)
#
# File ~/Desktop/SCHOOL CHATBOT/notebooks/agentic_chunker.py:31, in AgenticChunker.add_propositions(self, propositions)
#      29 def add_propositions(self, propositions):
#      30     for proposition in propositions:
# ---> 31         self.add_proposition(proposition)
#
# File ~/Desktop/SCHOOL CHATBOT/notebooks/agentic_chunker.py:44, in AgenticChunker.add_proposition(self, proposition)
#      41     self._create_new_chunk(proposition)
#      42     return
# ---> 44 chunk_id = self._find_relevant_chunk(proposition)
#      46 # If a chunk was found then add the proposition to it
#      47 if chunk_id:
#
# File ~/Desktop/SCHOOL CHATBOT/notebooks/agentic_chunker.py:284, in AgenticChunker._find_relevant_chunk(self, proposition)
#     250 PROMPT = ChatPromptTemplate.from_messages(
#     251     [
#     252         (
#    (...)
#     279     ]
#     280 )
#     282 runnable = PROMPT | self.llm
# --> 284 chunk_found = runnable.invoke({
#     285     "proposition": proposition,
#     286     "current_chunk_outline": current_chunk_outline
#     287 }).content
#     289 # Pydantic data class
#     290 class ChunkID(BaseModel):
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/runnables/base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:277, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#    (...)
#     272     **kwargs: Any,
#     273 ) -> BaseMessage:
#     274     config = ensure_config(config)
#     275     return cast(
#     276         ChatGeneration,
# --> 277         self.generate_prompt(
#     278             [self._convert_input(input)],
#     279             stop=stop,
#     280             callbacks=config.get("callbacks"),
#     281             tags=config.get("tags"),
#     282             metadata=config.get("metadata"),
#     283             run_name=config.get("run_name"),
#     284             run_id=config.pop("run_id", None),
#     285             **kwargs,
#     286         ).generations[0][0],
#     287     ).message
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:777, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     769 def generate_prompt(
#     770     self,
#     771     prompts: List[PromptValue],
#    (...)
#     774     **kwargs: Any,
#     775 ) -> LLMResult:
#     776     prompt_messages = [p.to_messages() for p in prompts]
# --> 777     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:634, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     632         if run_managers:
#     633             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 634         raise e
#     635 flattened_outputs = [
#     636     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     637     for res in results
#     638 ]
#     639 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:624, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621 for i, m in enumerate(messages):
#     622     try:
#     623         results.append(
# --> 624             self._generate_with_cache(
#     625                 m,
#     626                 stop=stop,
#     627                 run_manager=run_managers[i] if run_managers else None,
#     628                 **kwargs,
#     629             )
#     630         )
#     631     except BaseException as e:
#     632         if run_managers:
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:846, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     844 else:
#     845     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 846         result = self._generate(
#     847             messages, stop=stop, run_manager=run_manager, **kwargs
#     848         )
#     849     else:
#     850         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_community/chat_models/openai.py:441, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     435 message_dicts, params = self._create_message_dicts(messages, stop)
#     436 params = {
#     437     **params,
#     438     **({"stream": stream} if stream is not None else {}),
#     439     **kwargs,
#     440 }
# --> 441 response = self.completion_with_retry(
#     442     messages=message_dicts, run_manager=run_manager, **params
#     443 )
#     444 return self._create_chat_result(response)
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/langchain_community/chat_models/openai.py:356, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     354 """Use tenacity to retry the completion call."""
#     355 if is_openai_v1():
# --> 356     return self.client.create(**kwargs)
#     358 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     360 @retry_decorator
#     361 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_utils/_utils.py:274, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     272             msg = f"Missing required argument: {quote(missing[0])}"
#     273     raise TypeError(msg)
# --> 274 return func(*args, **kwargs)
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/resources/chat/completions.py:668, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     633 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     634 def create(
#     635     self,
#    (...)
#     665     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     666 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     667     validate_response_format(response_format)
# --> 668     return self._post(
#     669         "/chat/completions",
#     670         body=maybe_transform(
#     671             {
#     672                 "messages": messages,
#     673                 "model": model,
#     674                 "frequency_penalty": frequency_penalty,
#     675                 "function_call": function_call,
#     676                 "functions": functions,
#     677                 "logit_bias": logit_bias,
#     678                 "logprobs": logprobs,
#     679                 "max_tokens": max_tokens,
#     680                 "n": n,
#     681                 "parallel_tool_calls": parallel_tool_calls,
#     682                 "presence_penalty": presence_penalty,
#     683                 "response_format": response_format,
#     684                 "seed": seed,
#     685                 "service_tier": service_tier,
#     686                 "stop": stop,
#     687                 "stream": stream,
#     688                 "stream_options": stream_options,
#     689                 "temperature": temperature,
#     690                 "tool_choice": tool_choice,
#     691                 "tools": tools,
#     692                 "top_logprobs": top_logprobs,
#     693                 "top_p": top_p,
#     694                 "user": user,
#     695             },
#     696             completion_create_params.CompletionCreateParams,
#     697         ),
#     698         options=make_request_options(
#     699             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     700         ),
#     701         cast_to=ChatCompletion,
#     702         stream=stream or False,
#     703         stream_cls=Stream[ChatCompletionChunk],
#     704     )
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1260, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1246 def post(
#    1247     self,
#    1248     path: str,
#    (...)
#    1255     stream_cls: type[_StreamT] | None = None,
#    1256 ) -> ResponseT | _StreamT:
#    1257     opts = FinalRequestOptions.construct(
#    1258         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1259     )
# -> 1260     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:937, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     928 def request(
#     929     self,
#     930     cast_to: Type[ResponseT],
#    (...)
#     935     stream_cls: type[_StreamT] | None = None,
#     936 ) -> ResponseT | _StreamT:
# --> 937     return self._request(
#     938         cast_to=cast_to,
#     939         options=options,
#     940         stream=stream,
#     941         stream_cls=stream_cls,
#     942         remaining_retries=remaining_retries,
#     943     )
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1026, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1024 if retries > 0 and self._should_retry(err.response):
#    1025     err.response.close()
# -> 1026     return self._retry_request(
#    1027         input_options,
#    1028         cast_to,
#    1029         retries,
#    1030         err.response.headers,
#    1031         stream=stream,
#    1032         stream_cls=stream_cls,
#    1033     )
#    1035 # If the response is streamed then we need to explicitly read the response
#    1036 # to completion before attempting to access the response text.
#    1037 if not err.response.is_closed:
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1075, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1071 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1072 # different thread if necessary.
#    1073 time.sleep(timeout)
# -> 1075 return self._request(
#    1076     options=options,
#    1077     cast_to=cast_to,
#    1078     remaining_retries=remaining,
#    1079     stream=stream,
#    1080     stream_cls=stream_cls,
#    1081 )
#
# File ~/Desktop/SCHOOL CHATBOT/chatvenv/lib/python3.12/site-packages/openai/_base_client.py:1041, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1038         err.response.read()
#    1040     log.debug("Re-raising status error")
# -> 1041     raise self._make_status_error_from_response(err.response) from None
#    1043 return self._process_response(
#    1044     cast_to=cast_to,
#    1045     options=options,
#    (...)
#    1049     retries_taken=options.get_max_retries(self.max_retries) - retries,
#    1050 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
ac.pretty_print_chunks()
# Out:
# You have 26 chunks
#
# Chunk #0
# Chunk ID: cb0f2
# Summary: This chunk details the comprehensive guidelines and regulations for membership intake processes, hazing policies, and event scheduling for student organizations at Georgia State University, emphasizing the mandatory compliance with SEAL's procedures and the university's student conduct codes.
# Propositions:
#     -No organization/club shall intake members prior to meeting the college/university's requirements.
#     -No organization/club shall intake members prior to meeting the requirements of its national organization.
#     -No intake activity should be held without the presence of the advisor(s).
#     -HAZING in any form is prohibited.
#     -Physical abuse is prohibited.
#     -Physical and mental abuse will not be tolerated.
#     -A list of intended candidates must be filed with SEAL.
#     -The list of intended candidates must be filed the following day after any informational meetings.
#     -All students interested in joining a student organization must be authorized at Georgia State University (GSU).
#     -All students interested in joining a student organization at Georgia State University (GSU) must take the Anti-Hazing certification course.
#     -The Anti-Hazing certification course is sponsored by the Student Engagement and Leadership Center (SEAL).
#     -The Georgia State University (GSU) Anti-Hazing certification course is available on CANVAS.
#     -The Georgia State University (GSU) Anti-Hazing certification course is continuously available.
#     -The following text pertains to expectations and requirements regarding membership intake programs for all recognized Social Non-Greek (NPHC) and Music Organizations at Georgia State University (GSU).
#     -All organizations at GSU are always required to follow the Membership Intake Program (MIP).
#     -The Membership Intake Program (MIP) is developed and disseminated by the SEAL.
#     -All organizations at GSU are required to follow the Membership Intake Program (MIP) disseminated by their respective Regional/National Headquarters.
#     -Intakes occur two times a year.
#     -One intake occurs in the fall.
#     -The fall intake occurs in the month of October.
#     -Another intake occurs in the spring.
#     -The spring intake occurs in the month of February.
#     -Any changes to the intake schedule must first be cleared with SEAL.
#     -A person must pick up a Membership Intake Process (MIP) packet from the Student Engagement and Leadership (SEAL).
#     -A person must complete all required forms for Membership Intake Process (MIP).
#     -A person must submit all completed forms for Membership Intake Process (MIP) to the Student Engagement and Leadership (SEAL).
#     -A person must notify the Student Engagement and Leadership (SEAL) of any subsequent changes in the status of Membership Intake Process (MIP) candidate(s).
#     -A person must notify the Student Engagement and Leadership (SEAL) of any results of the Membership Intake Process (MIP) candidate(s) status.
#     -The verification must confirm that approval from the Regional/National Headquarters has been granted.
#     -The approval must be for conducting membership intake.
#     -Each chapter must submit a calendar of events for intake activities.
#     -Each chapter must submit an Intent to Conduct Form.
#     -Each chapter must submit the Hazing Compliance Form.
#     -The submission of the calendar of events, Intent to Conduct Form, and the Hazing Compliance Form must occur at the initial notification of SEAL's intent to conduct membership intake.
#     -The calendar of events must include a timetable of all intake activities.
#     -The timetable must specify places of the intake activities.
#     -The timetable must specify dates of the intake activities.
#     -The timetable must specify times of the intake activities.
#     -Activities to be included on the calendar are unspecified and the sentence is incomplete.
#     -All intake activities must end before the start of homecoming in the fall semester.
#     -All intake activities must end before the start of spring fest activities in the spring semester.
#     -Intake activities must pause during mid-term exams.
#     -The selection date(s) for new members must be established.
#     -New members are presented.
#     -A copy of the University Facility Use Form must be submitted if the presentation includes a probate show.
#     -A copy of the protocol must be submitted if the presentation includes a probate show.
#     -The Intent to Conduct Membership Intake Form must contain the original signature of the chapter president.
#     -The Intent to Conduct Membership Intake Form must contain the original signature of the primary chapter advisor.
#     -All organizations that are not NPHC authorized will follow the guidance found in the form.
#     -The guidance for the organizations is found in the form located at the link life/clubs/docs/Form%20Hazing%20form%20simple%20mem%20intake.pdf.
#     -New members must be cleared by the SEAL office.
#     -The presentation of new members will be placed within the calendar set forth by the SEAL.
#     -The presentation of new members will be scheduled at the discretion of the SEAL.
#     -Vulgarity will not be tolerated.
#     -No alcoholic substances will be permitted.
#     -No drugs will be permitted.
#     -In the event of aggressive behavior during a presentation, those identified will be referred to the Office of Student Conduct.
#     -The Office of Student Conduct will determine penalties for inappropriate behavior.
#     -Disruptions by other organizations will not be tolerated.
#     -Talking over the presentation organization is included in the disruptions that will not be tolerated.
#     -Intake activities must take place on the campus.
#     -An updated membership roster must be turned in to SEAL.
#     -The updated membership roster must be turned in immediately after the conclusion of the intake process.
#     -The updated membership roster must be turned in within two days of induction.
#     -Each Greek letter organization may conduct one Membership Intake Process (MIP) in the spring.
#     -Each Greek letter organization may conduct one Membership Intake Process (MIP) in the fall.
#     -If the proper paperwork is not submitted within the time designated by SEAL, intake activity will be
#     -An organization's progress in their process does not affect the denial or suspension of something.
#     -All candidates and members must be excluded from membership activities.
#     -Candidates and members must complete the Anti-hazing course on CANVAS to avoid exclusion from membership activities.
#     -There is an Anti-hazing course available on CANVAS.
#     -To complete the CANVAS Anti-hazing course, one must click a link.
#     -The link to complete the CANVAS Anti-hazing course is https://grambling.instructure.com/courses/11165.
#     -Violations of the intake process may result in probation for the involved individuals or organization.
#     -Violations of the intake process may result in immediate interim suspension for the involved individuals or organization until the investigation is complete.
#     -Violations of the intake process may result in expulsion for the involved individuals or organization if the investigation confirms that hazing was involved in the activities of the organization.
#     -The decision whether the chapter will be placed on probation or receive automatic suspension is based upon the infractions.
#     -The decision about probation or suspension is at the discretion of the SEAL Director.
#     -The decision about probation or suspension is at the discretion of the Vice President for Student Affairs.
#     -The decision about probation or suspension is at the discretion of another University governing body.
#     -The adjudication of cases may be referred to the Office of Student Conduct.
#     -The referral of cases to the Office of Student Conduct is at the discretion of SEAL.
#     -The referral of cases to the Office of Student Conduct is at the discretion of the Vice President for student affairs or its surrogate.
#     -Investigation may be of hazing violations.
#     -Violations are not limited to the following list.
#     -Violations include certain actions or behaviors that are not specified here.
#     -There is an intentional submission of improper paperwork.
#     -Improper paperwork includes changing of dates on forms.
#     -Improper paperwork includes falsifying original signatures.
#     -Holding membership intake without conforming to the intake guidelines set forth in the handbook is an action.
#     -There are intake guidelines set forth in the handbook.
#     -All students must comply with the GSU Student Code of Conduct.
#     -All students must comply with the requirements of the GSU Student Code of Conduct.
#     -All students participating in membership intake must comply with the intake guidelines set forth in the handbook.
#     -All incidents of hazing must be reported first to SEAL immediately.
#     -All incidents of hazing must be reported to SEAL before any organization outside the University is notified.
#     -Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by advisors.
#     -Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by other University personnel.
#     -Failure by any student to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.
#     -All incidents of hazing must be reported first to SEAL immediately.
#     -All incidents of hazing must be reported to SEAL before any organization outside the University is notified.
#     -Disregard of guidelines for any activity related to intake is an action.
#     -Any activity related to intake conducted in defiance of previous warnings by advisors is an action.
#     -Any activity related to intake conducted in defiance of previous warnings by other University personnel is an action.
#     -Intake activities must not begin without the knowledge of the SEAL Director.
#     -Intake activities must not begin without the signed approval of the SEAL Director.
#     -The chapter must adhere to the intake guidelines.
#     -If intake activities begin without the knowledge of the SEAL Director, the intake activities will cease immediately.
#     -If intake activities begin without the signed approval of the SEAL Director, the intake activities will cease immediately.
#     -If the chapter has not adhered to the intake guidelines, the intake activities will cease immediately.
#     -The chapter may be placed on suspension if the intake activities begin without the knowledge of the SEAL Director.
#     -The chapter may be placed on suspension if the intake activities begin without the signed approval of the SEAL Director.
#     -The chapter may be placed on suspension if the chapter has not adhered to the intake guidelines.
#     -Sanctions will be administered at the discretion of the SEAL Director.
#     -The Department of Student Activities staff are available to assist student organizations as needed.
#     -Grambling State University grants recognition to student organizations.
#     -The organization is committed to improving the quality of student life.
#     -Students must be currently registered at GSU to participate in membership intake.
#     -Students must be registered for a minimum of 12 semester hours at GSU to participate in membership intake.
#     -Students must have completed 30 hours at GSU before the semester within which they are establishing eligibility to participate in membership intake.
#     -Students must meet certain criteria to participate in membership intake.
#     -Completed the semester at GSU prior to intake.
#     -The entity has had no disciplinary sanctions at the University during the past two years.
#     -The Office of Student Engagement and Leadership officially cleared the policy.
#     -Chapters are forbidden to request transcripts for intake purposes.
#     -Membership intake must occur during the fall semester.
#     -Alternatively, membership intake must occur during the spring semester.
#     -Membership intake must occur during the time allotted for intake purposes.
#
#
#
# Chunk #1
# Chunk ID: 806a0
# Summary: This chunk contains information about the prohibition and legal status of different forms of abuse.
# Propositions:
#     -Mental abuse is prohibited.
#
#
#
# Chunk #2
# Chunk ID: 814e1
# Summary: This chunk outlines the regulations, affiliations, and compliance requirements of university organizations, particularly focusing on music and band groups at institutions like GSU, and their adherence to university and national governing bodies.
# Propositions:
#     -The SEAL is associated with Georgia State University (GSU).
#     -If the organization is nationally affiliated, the chapter must provide verification.
#     -All organizations that are not GSU authorized Music/Band organizations will follow the guidance found in the form.
#     -All organizations are responsible for visitors who are members of those organizations.
#     -This includes the national office of the organization.
#     -Grambling State University is host to organizations affiliated with the National Pan Hellenic Council.
#     -Grambling State University is host to organizations affiliated with the national music and band sororities/fraternities.
#     -The organizations are affiliated through the music department.
#     -The organizations have requirements and conditions to fulfill through their national governing bodies.
#     -The organization will comply with the mission of the University.
#     -The organization will comply with the mission of its national body.
#     -The organizations on the list must follow the University guidelines.
#     -Phi Mu Alpha Sinfonia is a band/music organization.
#     -Sigma Alpha Iota is an international music fraternity.
#     -Tau Beta Sigma is an honorary band sorority.
#
#
#
# Chunk #3
# Chunk ID: aeb3d
# Summary: This chunk outlines the comprehensive guidelines and protocols for fraternity and sorority chapters regarding the education, initiation, and presentation of new members, emphasizing the importance of proper planning, adherence to policies, and the responsibilities of organizing events within the framework of the National Pan-Hellenic Council.
# Propositions:
#     -All chapters are responsible for educating undergraduates.
#     -Chapters must educate undergraduates regarding all MIP policies.
#     -A chapter must complete certain tasks when it initiates the MIP.
#     -The start date of the new member's official process/education must be established.
#     -The end date of the new member's official process/education must be established.
#     -All activities in the new member's official process/education must be included between the start and end dates.
#     -An initiation date exists.
#     -The presentation of new members may include a probate show.
#     -A copy of the Activity Clearance form must be submitted if the presentation includes a probate show.
#     -The University Facility Use Form is required to proceed with the activity of presenting new members with a probate show.
#     -The protocol is required to proceed with the activity of presenting new members with a probate show.
#     -The Activity Clearance form is required to proceed with the activity of presenting new members with a probate show.
#     -The required documents must be submitted two weeks in advance of the activity involving the presentation of new members with a probate show.
#     -The presentation of new members may include a probate show.
#     -If the presentation of new members does not include a probate show, then a specified event or consequence occurs.
#     -The method used should be included on the Activity Clearance Form.
#     -The presentation of new members takes place after they have been cleared by the SEAL office.
#     -Walking through the presenters' show is included in the disruptions that will not be tolerated.
#     -The duration of the probate show should be no longer than three hours.
#     -Following the probate show, members must vacate the area within 30 minutes.
#     -The presenting organization will be responsible for ensuring the site is left in its original state.
#     -The presenting organization's responsibility occurs after the use of the site.
#     -The intake process concludes with induction.
#     -Failure by any advisor to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.
#     -Failure to adhere to Presentation of New Membership Guidelines by any student will be subject to disciplinary sanction.
#     -Failure to adhere to Presentation of New Membership Guidelines by any advisor will be subject to disciplinary sanction.
#     -Proper planning is considered the key to any successful event.
#     -Events taking place within the Favrot Student Union are supported by the student union staff.
#     -NPHC stands for National Pan-Hellenic Council.
#     -NPHC includes fraternities.
#     -NPHC includes sororities.
#     -Chapters are forbidden to send students to the registrar’s office.
#     -All chapters must conduct membership intake.
#
#
#
# Chunk #4
# Chunk ID: 6bc03
# Summary: This chunk focuses on the discussion and approval processes for procedures and methods.
# Propositions:
#     -Procedures are mentioned.
#     -The method used should be discussed before approval will be granted.
#
#
#
# Chunk #5
# Chunk ID: 8ed83
# Summary: This chunk contains suggestions for suitable activities for various contexts or occasions.
# Propositions:
#     -Appropriate activities are mentioned.
#
#
#
# Chunk #6
# Chunk ID: 2f5fc
# Summary: This chunk contains information about the requirements and paperwork protocols for completing tasks.
# Propositions:
#     -The tasks must be completed with SEAL.
#     -Improper paperwork includes submission of incomplete paperwork.
#
#
#
# Chunk #7
# Chunk ID: bdaff
# Summary: This chunk discusses the various objectives and types of meetings.
# Propositions:
#     -Meetings can be informational.
#     -Meetings can be held to generate or address interest.
#
#
#
# Chunk #8
# Chunk ID: 4baa3
# Summary: This chunk contains policies or rules regarding acceptable language and dress code standards.
# Propositions:
#     -Profanity will not be tolerated.
#     -No attire that is explicit or revealing will be permitted.
#
#
#
# Chunk #9
# Chunk ID: b2caf
# Summary: This chunk contains information about the procedures and actions taken by the University Police Department during campus events.
# Propositions:
#     -The University Police Department will determine if the presentation continues.
#     -Vacating the area within 30 minutes will help with crowd disbursement.
#
#
#
# Chunk #10
# Chunk ID: f8a9c
# Summary: This chunk contains information about different behaviors that can disrupt presentations.
# Propositions:
#     -Heckling is a form of talking over the presentation organization.
#     -Making rude remarks is a form of talking over the presentation organization.
#
#
#
# Chunk #11
# Chunk ID: bf020
# Summary: This chunk contains information about university governance and administrative bodies.
# Propositions:
#     -The Office of Student Conduct is a University governing body.
#
#
#
# Chunk #12
# Chunk ID: 88c23
# Summary: This chunk contains information about the functions and characteristics of the GSU Police Department.
# Propositions:
#     -The GSU Police Department is a University governing body.
#
#
#
# Chunk #13
# Chunk ID: 6e629
# Summary: This chunk contains information about the usage and examples of the word 'to'.
# Propositions:
#     -The input contains the word 'to'.
#
#
#
# Chunk #14
# Chunk ID: 6648b
# Summary: This chunk contains information about the different levels and locations of offices within an organization.
# Propositions:
#     -This includes the regional office of the organization.
#     -This includes the district office of the organization.
#     -This includes the national office of the organization.
#     -This includes the regional office of the organization.
#     -This includes the district office of the organization.
#
#
#
# Chunk #15
# Chunk ID: b4d92
# Summary: This chunk contains information about the recognitions and acknowledgments granted by Grambling State University.
# Propositions:
#     -Grambling State University grants recognition with the understanding.
#
#
#
# Chunk #16
# Chunk ID: 95eee
# Summary: This chunk contains information about the organization's service and engagement initiatives within the community and educational institutions.
# Propositions:
#     -The organization aims to build strong community relationships.
#     -The organization provides service to the community.
#     -The organization provides service to the school.
#
#
#
# Chunk #17
# Chunk ID: 7f240
# Summary: This chunk discusses the various types of social relationships and the interactions that define them within a societal context.
# Propositions:
#     -Social relationships are connections between individuals in a society.
#     -Social relationships involve interactions among individuals.
#     -Social relationships can be of different types such as friendships, familial bonds, and professional associations.
#
#
#
# Chunk #18
# Chunk ID: cf74d
# Summary: This chunk contains information about the organization's values and commitments in education.
# Propositions:
#     -The organization is committed to scholastic achievement.
#
#
#
# Chunk #19
# Chunk ID: e8f3c
# Summary: This chunk contains information about the organization's commitments and initiatives.
# Propositions:
#     -The organization is committed to leadership development.
#
#
#
# Chunk #20
# Chunk ID: 24974
# Summary: This chunk contains information about various organizations and their details.
# Propositions:
#     -A list of organizations exists.
#
#
#
# Chunk #21
# Chunk ID: d0e0f
# Summary: This chunk contains information about Greek letter organizations, their affiliations, and incorporation statuses.
# Propositions:
#     -Alpha Phi Alpha is a fraternity.
#     -Alpha Phi Alpha is part of NPHC.
#     -Alpha Phi Alpha has the designation 'Inc.'
#     -Iota Phi Theta is a fraternity.
#     -Kappa Alpha Psi is a fraternity.
#     -Sigma Gamma Rho is a sorority.
#     -Sigma Gamma Rho has the designation 'Inc.'
#     -Omega Psi Phi is a fraternity.
#     -Omega Psi Phi is part of NPHC.
#     -Omega Psi Phi has the designation 'Inc.'
#     -Zeta Phi Beta is part of NPHC.
#     -Zeta Phi Beta has the designation 'Inc.'
#     -Phi Beta Sigma has the designation 'Inc.'
#     -Phi Mu Alpha Sinfonia is a fraternity.
#     -Phi Mu Alpha Sinfonia has the designation 'Inc.'
#
#
#
# Chunk #22
# Chunk ID: 3ccd1
# Summary: This chunk contains information about different Greek letter organizations, including their membership in the National Pan-Hellenic Council (NPHC), their status as sororities or fraternities, and their incorporation status.
# Propositions:
#     -Alpha Kappa Alpha is a sorority.
#     -Alpha Kappa Alpha is part of NPHC.
#     -Alpha Kappa Alpha has the designation 'Inc.'
#     -Iota Phi Theta is part of NPHC.
#     -Iota Phi Theta has the designation 'Inc.'
#     -Delta Sigma Theta is a sorority.
#     -Delta Sigma Theta is part of NPHC.
#     -Delta Sigma Theta has the designation 'Inc.'
#     -Kappa Alpha Psi is part of NPHC.
#     -Kappa Alpha Psi has the designation 'Inc.'
#     -Sigma Gamma Rho is part of NPHC.
#     -Zeta Phi Beta is a sorority.
#     -Phi Beta Sigma is a fraternity.
#     -Phi Beta Sigma is part of NPHC.
#     -Kappa Kappa Psi is a fraternity.
#
#
#
# Chunk #23
# Chunk ID: 8c38e
# Summary: This chunk contains information about credit transfer policies for dual high school and university programs.
# Propositions:
#     -Hours earned in a dual high school GSU undergraduate program can be used for qualifying hours earned.
#
#
#
# Chunk #24
# Chunk ID: f8c83
# Summary: This chunk details the criteria and academic achievements necessary for a student to be considered a full-time sophomore or higher at GSU.
# Propositions:
#     -A full-time GSU student is a student who has earned thirty (30) academic credit hours at GSU.
#     -The academic credit hours earned at GSU by the full-time GSU student are non-remedial.
#     -A full-time GSU student is officially classified as a sophomore or above at the end of the previous spring semester.
#     -Has a cumulative grade point average of at least 50.
#     -Was enrolled full-time at GSU.
#     -The entity is in good standing academically with the University.
#
#
#
# Chunk #25
# Chunk ID: cf2fb
# Summary: This chunk contains information about the specific procedures and purposes for requesting transcripts through the Office of Student Clubs and Organizations at an educational institution.
# Propositions:
#     -Transcripts can only be requested through the Office of Student Clubs and Organizations.
#     -The purpose of requesting transcripts through the Office of Student Clubs and Organizations is for membership intake.

# %%
chunks = ac.get_chunks(get_type='dict')

# %%
chunks
# Out:
# {'cb0f2': {'chunk_id': 'cb0f2',
#   'propositions': ["No organization/club shall intake members prior to meeting the college/university's requirements.",
#    'No organization/club shall intake members prior to meeting the requirements of its national organization.',
#    'No intake activity should be held without the presence of the advisor(s).',
#    'HAZING in any form is prohibited.',
#    'Physical abuse is prohibited.',
#    'Physical and mental abuse will not be tolerated.',
#    'A list of intended candidates must be filed with SEAL.',
#    'The list of intended candidates must be filed the following day after any informational meetings.',
#    'All students interested in joining a student organization must be authorized at Georgia State University (GSU).',
#    'All students interested in joining a student organization at Georgia State University (GSU) must take the Anti-Hazing certification course.',
#    'The Anti-Hazing certification course is sponsored by the Student Engagement and Leadership Center (SEAL).',
#    'The Georgia State University (GSU) Anti-Hazing certification course is available on CANVAS.',
#    'The Georgia State University (GSU) Anti-Hazing certification course is continuously available.',
#    'The following text pertains to expectations and requirements regarding membership intake programs for all recognized Social Non-Greek (NPHC) and Music Organizations at Georgia State University (GSU).',
#    'All organizations at GSU are always required to follow the Membership Intake Program (MIP).',
#    'The Membership Intake Program (MIP) is developed and disseminated by the SEAL.',
#    'All organizations at GSU are required to follow the Membership Intake Program (MIP) disseminated by their respective Regional/National Headquarters.',
#    'Intakes occur two times a year.',
#    'One intake occurs in the fall.',
#    'The fall intake occurs in the month of October.',
#    'Another intake occurs in the spring.',
#    'The spring intake occurs in the month of February.',
#    'Any changes to the intake schedule must first be cleared with SEAL.',
#    'A person must pick up a Membership Intake Process (MIP) packet from the Student Engagement and Leadership (SEAL).',
#    'A person must complete all required forms for Membership Intake Process (MIP).',
#    'A person must submit all completed forms for Membership Intake Process (MIP) to the Student Engagement and Leadership (SEAL).',
#    'A person must notify the Student Engagement and Leadership (SEAL) of any subsequent changes in the status of Membership Intake Process (MIP) candidate(s).',
#    'A person must notify the Student Engagement and Leadership (SEAL) of any results of the Membership Intake Process (MIP) candidate(s) status.',
#    'The verification must confirm that approval from the Regional/National Headquarters has been granted.',
#    'The approval must be for conducting membership intake.',
#    'Each chapter must submit a calendar of events for intake activities.',
#    'Each chapter must submit an Intent to Conduct Form.',
#    'Each chapter must submit the Hazing Compliance Form.',
#    "The submission of the calendar of events, Intent to Conduct Form, and the Hazing Compliance Form must occur at the initial notification of SEAL's intent to conduct membership intake.",
#    'The calendar of events must include a timetable of all intake activities.',
#    'The timetable must specify places of the intake activities.',
#    'The timetable must specify dates of the intake activities.',
#    'The timetable must specify times of the intake activities.',
#    'Activities to be included on the calendar are unspecified and the sentence is incomplete.',
#    'All intake activities must end before the start of homecoming in the fall semester.',
#    'All intake activities must end before the start of spring fest activities in the spring semester.',
#    'Intake activities must pause during mid-term exams.',
#    'The selection date(s) for new members must be established.',
#    'New members are presented.',
#    'A copy of the University Facility Use Form must be submitted if the presentation includes a probate show.',
#    'A copy of the protocol must be submitted if the presentation includes a probate show.',
#    'The Intent to Conduct Membership Intake Form must contain the original signature of the chapter president.',
#    'The Intent to Conduct Membership Intake Form must contain the original signature of the primary chapter advisor.',
#    'All organizations that are not NPHC authorized will follow the guidance found in the form.',
#    'The guidance for the organizations is found in the form located at the link life/clubs/docs/Form%20Hazing%20form%20simple%20mem%20intake.pdf.',
#    'New members must be cleared by the SEAL office.',
#    'The presentation of new members will be placed within the calendar set forth by the SEAL.',
#    'The presentation of new members will be scheduled at the discretion of the SEAL.',
#    'Vulgarity will not be tolerated.',
#    'No alcoholic substances will be permitted.',
#    'No drugs will be permitted.',
#    'In the event of aggressive behavior during a presentation, those identified will be referred to the Office of Student Conduct.',
#    'The Office of Student Conduct will determine penalties for inappropriate behavior.',
#    'Disruptions by other organizations will not be tolerated.',
#    'Talking over the presentation organization is included in the disruptions that will not be tolerated.',
#    'Intake activities must take place on the campus.',
#    'An updated membership roster must be turned in to SEAL.',
#    'The updated membership roster must be turned in immediately after the conclusion of the intake process.',
#    'The updated membership roster must be turned in within two days of induction.',
#    'Each Greek letter organization may conduct one Membership Intake Process (MIP) in the spring.',
#    'Each Greek letter organization may conduct one Membership Intake Process (MIP) in the fall.',
#    'If the proper paperwork is not submitted within the time designated by SEAL, intake activity will be',
#    "An organization's progress in their process does not affect the denial or suspension of something.",
#    'All candidates and members must be excluded from membership activities.',
#    'Candidates and members must complete the Anti-hazing course on CANVAS to avoid exclusion from membership activities.',
#    'There is an Anti-hazing course available on CANVAS.',
#    'To complete the CANVAS Anti-hazing course, one must click a link.',
#    'The link to complete the CANVAS Anti-hazing course is https://grambling.instructure.com/courses/11165.',
#    'Violations of the intake process may result in probation for the involved individuals or organization.',
#    'Violations of the intake process may result in immediate interim suspension for the involved individuals or organization until the investigation is complete.',
#    'Violations of the intake process may result in expulsion for the involved individuals or organization if the investigation confirms that hazing was involved in the activities of the organization.',
#    'The decision whether the chapter will be placed on probation or receive automatic suspension is based upon the infractions.',
#    'The decision about probation or suspension is at the discretion of the SEAL Director.',
#    'The decision about probation or suspension is at the discretion of the Vice President for Student Affairs.',
#    'The decision about probation or suspension is at the discretion of another University governing body.',
#    'The adjudication of cases may be referred to the Office of Student Conduct.',
#    'The referral of cases to the Office of Student Conduct is at the discretion of SEAL.',
#    'The referral of cases to the Office of Student Conduct is at the discretion of the Vice President for student affairs or its surrogate.',
#    'Investigation may be of hazing violations.',
#    'Violations are not limited to the following list.',
#    'Violations include certain actions or behaviors that are not specified here.',
#    'There is an intentional submission of improper paperwork.',
#    'Improper paperwork includes changing of dates on forms.',
#    'Improper paperwork includes falsifying original signatures.',
#    'Holding membership intake without conforming to the intake guidelines set forth in the handbook is an action.',
#    'There are intake guidelines set forth in the handbook.',
#    'All students must comply with the GSU Student Code of Conduct.',
#    'All students must comply with the requirements of the GSU Student Code of Conduct.',
#    'All students participating in membership intake must comply with the intake guidelines set forth in the handbook.',
#    'All incidents of hazing must be reported first to SEAL immediately.',
#    'All incidents of hazing must be reported to SEAL before any organization outside the University is notified.',
#    'Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by advisors.',
#    'Disregard of guidelines for any activity related to intake occurs in defiance of previous warnings by other University personnel.',
#    'Failure by any student to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.',
#    'All incidents of hazing must be reported first to SEAL immediately.',
#    'All incidents of hazing must be reported to SEAL before any organization outside the University is notified.',
#    'Disregard of guidelines for any activity related to intake is an action.',
#    'Any activity related to intake conducted in defiance of previous warnings by advisors is an action.',
#    'Any activity related to intake conducted in defiance of previous warnings by other University personnel is an action.',
#    'Intake activities must not begin without the knowledge of the SEAL Director.',
#    'Intake activities must not begin without the signed approval of the SEAL Director.',
#    'The chapter must adhere to the intake guidelines.',
#    'If intake activities begin without the knowledge of the SEAL Director, the intake activities will cease immediately.',
#    'If intake activities begin without the signed approval of the SEAL Director, the intake activities will cease immediately.',
#    'If the chapter has not adhered to the intake guidelines, the intake activities will cease immediately.',
#    'The chapter may be placed on suspension if the intake activities begin without the knowledge of the SEAL Director.',
#    'The chapter may be placed on suspension if the intake activities begin without the signed approval of the SEAL Director.',
#    'The chapter may be placed on suspension if the chapter has not adhered to the intake guidelines.',
#    'Sanctions will be administered at the discretion of the SEAL Director.',
#    'The Department of Student Activities staff are available to assist student organizations as needed.',
#    'Grambling State University grants recognition to student organizations.',
#    'The organization is committed to improving the quality of student life.',
#    'Students must be currently registered at GSU to participate in membership intake.',
#    'Students must be registered for a minimum of 12 semester hours at GSU to participate in membership intake.',
#    'Students must have completed 30 hours at GSU before the semester within which they are establishing eligibility to participate in membership intake.',
#    'Students must meet certain criteria to participate in membership intake.',
#    'Completed the semester at GSU prior to intake.',
#    'The entity has had no disciplinary sanctions at the University during the past two years.',
#    'The Office of Student Engagement and Leadership officially cleared the policy.',
#    'Chapters are forbidden to request transcripts for intake purposes.',
#    'Membership intake must occur during the fall semester.',
#    'Alternatively, membership intake must occur during the spring semester.',
#    'Membership intake must occur during the time allotted for intake purposes.'],
#   'title': 'University Membership Intake & Conduct Policies',
#   'summary': "This chunk details the comprehensive guidelines and regulations for membership intake processes, hazing policies, and event scheduling for student organizations at Georgia State University, emphasizing the mandatory compliance with SEAL's procedures and the university's student conduct codes.",
#   'chunk_index': 0},
#  '806a0': {'chunk_id': '806a0',
#   'propositions': ['Mental abuse is prohibited.'],
#   'title': 'Legal Status of Abuse',
#   'summary': 'This chunk contains information about the prohibition and legal status of different forms of abuse.',
#   'chunk_index': 1},
#  '814e1': {'chunk_id': '814e1',
#   'propositions': ['The SEAL is associated with Georgia State University (GSU).',
#    'If the organization is nationally affiliated, the chapter must provide verification.',
#    'All organizations that are not GSU authorized Music/Band organizations will follow the guidance found in the form.',
#    'All organizations are responsible for visitors who are members of those organizations.',
#    'This includes the national office of the organization.',
#    'Grambling State University is host to organizations affiliated with the National Pan Hellenic Council.',
#    'Grambling State University is host to organizations affiliated with the national music and band sororities/fraternities.',
#    'The organizations are affiliated through the music department.',
#    'The organizations have requirements and conditions to fulfill through their national governing bodies.',
#    'The organization will comply with the mission of the University.',
#    'The organization will comply with the mission of its national body.',
#    'The organizations on the list must follow the University guidelines.',
#    'Phi Mu Alpha Sinfonia is a band/music organization.',
#    'Sigma Alpha Iota is an international music fraternity.',
#    'Tau Beta Sigma is an honorary band sorority.'],
#   'title': 'University & Music Organizations: Compliance and Affiliations',
#   'summary': 'This chunk outlines the regulations, affiliations, and compliance requirements of university organizations, particularly focusing on music and band groups at institutions like GSU, and their adherence to university and national governing bodies.',
#   'chunk_index': 2},
#  'aeb3d': {'chunk_id': 'aeb3d',
#   'propositions': ['All chapters are responsible for educating undergraduates.',
#    'Chapters must educate undergraduates regarding all MIP policies.',
#    'A chapter must complete certain tasks when it initiates the MIP.',
#    "The start date of the new member's official process/education must be established.",
#    "The end date of the new member's official process/education must be established.",
#    "All activities in the new member's official process/education must be included between the start and end dates.",
#    'An initiation date exists.',
#    'The presentation of new members may include a probate show.',
#    'A copy of the Activity Clearance form must be submitted if the presentation includes a probate show.',
#    'The University Facility Use Form is required to proceed with the activity of presenting new members with a probate show.',
#    'The protocol is required to proceed with the activity of presenting new members with a probate show.',
#    'The Activity Clearance form is required to proceed with the activity of presenting new members with a probate show.',
#    'The required documents must be submitted two weeks in advance of the activity involving the presentation of new members with a probate show.',
#    'The presentation of new members may include a probate show.',
#    'If the presentation of new members does not include a probate show, then a specified event or consequence occurs.',
#    'The method used should be included on the Activity Clearance Form.',
#    'The presentation of new members takes place after they have been cleared by the SEAL office.',
#    "Walking through the presenters' show is included in the disruptions that will not be tolerated.",
#    'The duration of the probate show should be no longer than three hours.',
#    'Following the probate show, members must vacate the area within 30 minutes.',
#    'The presenting organization will be responsible for ensuring the site is left in its original state.',
#    "The presenting organization's responsibility occurs after the use of the site.",
#    'The intake process concludes with induction.',
#    'Failure by any advisor to adhere to Presentation of New Membership Guidelines will be subject to disciplinary sanction.',
#    'Failure to adhere to Presentation of New Membership Guidelines by any student will be subject to disciplinary sanction.',
#    'Failure to adhere to Presentation of New Membership Guidelines by any advisor will be subject to disciplinary sanction.',
#    'Proper planning is considered the key to any successful event.',
#    'Events taking place within the Favrot Student Union are supported by the student union staff.',
#    'NPHC stands for National Pan-Hellenic Council.',
#    'NPHC includes fraternities.',
#    'NPHC includes sororities.',
#    'Chapters are forbidden to send students to the registrar’s office.',
#    'All chapters must conduct membership intake.'],
#   'title': 'Fraternity & Sorority New Member Education and Presentation Protocols',
#   'summary': 'This chunk outlines the comprehensive guidelines and protocols for fraternity and sorority chapters regarding the education, initiation, and presentation of new members, emphasizing the importance of proper planning, adherence to policies, and the responsibilities of organizing events within the framework of the National Pan-Hellenic Council.',
#   'chunk_index': 3},
#  '6bc03': {'chunk_id': '6bc03',
#   'propositions': ['Procedures are mentioned.',
#    'The method used should be discussed before approval will be granted.'],
#   'title': 'Discussion & Approval of Procedures and Methods',
#   'summary': 'This chunk focuses on the discussion and approval processes for procedures and methods.',
#   'chunk_index': 4},
#  '8ed83': {'chunk_id': '8ed83',
#   'propositions': ['Appropriate activities are mentioned.'],
#   'title': 'Activity Recommendations',
#   'summary': 'This chunk contains suggestions for suitable activities for various contexts or occasions.',
#   'chunk_index': 5},
#  '2f5fc': {'chunk_id': '2f5fc',
#   'propositions': ['The tasks must be completed with SEAL.',
#    'Improper paperwork includes submission of incomplete paperwork.'],
#   'title': 'Task Completion Protocols & Paperwork Requirements',
#   'summary': 'This chunk contains information about the requirements and paperwork protocols for completing tasks.',
#   'chunk_index': 6},
#  'bdaff': {'chunk_id': 'bdaff',
#   'propositions': ['Meetings can be informational.',
#    'Meetings can be held to generate or address interest.'],
#   'title': 'Types & Objectives of Meetings',
#   'summary': 'This chunk discusses the various objectives and types of meetings.',
#   'chunk_index': 7},
#  '4baa3': {'chunk_id': '4baa3',
#   'propositions': ['Profanity will not be tolerated.',
#    'No attire that is explicit or revealing will be permitted.'],
#   'title': 'Language & Dress Code Policies',
#   'summary': 'This chunk contains policies or rules regarding acceptable language and dress code standards.',
#   'chunk_index': 8},
#  'b2caf': {'chunk_id': 'b2caf',
#   'propositions': ['The University Police Department will determine if the presentation continues.',
#    'Vacating the area within 30 minutes will help with crowd disbursement.'],
#   'title': 'Event Security & Crowd Control Procedures',
#   'summary': 'This chunk contains information about the procedures and actions taken by the University Police Department during campus events.',
#   'chunk_index': 9},
#  'f8a9c': {'chunk_id': 'f8a9c',
#   'propositions': ['Heckling is a form of talking over the presentation organization.',
#    'Making rude remarks is a form of talking over the presentation organization.'],
#   'title': 'Disruptive Behaviors in Presentations',
#   'summary': 'This chunk contains information about different behaviors that can disrupt presentations.',
#   'chunk_index': 10},
#  'bf020': {'chunk_id': 'bf020',
#   'propositions': ['The Office of Student Conduct is a University governing body.'],
#   'title': 'University Governance',
#   'summary': 'This chunk contains information about university governance and administrative bodies.',
#   'chunk_index': 11},
#  '88c23': {'chunk_id': '88c23',
#   'propositions': ['The GSU Police Department is a University governing body.'],
#   'title': 'GSU Police Department Functions',
#   'summary': 'This chunk contains information about the functions and characteristics of the GSU Police Department.',
#   'chunk_index': 12},
#  '6e629': {'chunk_id': '6e629',
#   'propositions': ["The input contains the word 'to'."],
#   'title': 'Prepositions Usage',
#   'summary': "This chunk contains information about the usage and examples of the word 'to'.",
#   'chunk_index': 13},
#  '6648b': {'chunk_id': '6648b',
#   'propositions': ['This includes the regional office of the organization.',
#    'This includes the district office of the organization.',
#    'This includes the national office of the organization.',
#    'This includes the regional office of the organization.',
#    'This includes the district office of the organization.'],
#   'title': 'Organizational Office Levels & Locations',
#   'summary': 'This chunk contains information about the different levels and locations of offices within an organization.',
#   'chunk_index': 14},
#  'b4d92': {'chunk_id': 'b4d92',
#   'propositions': ['Grambling State University grants recognition with the understanding.'],
#   'title': 'University Awards & Honors',
#   'summary': 'This chunk contains information about the recognitions and acknowledgments granted by Grambling State University.',
#   'chunk_index': 15},
#  '95eee': {'chunk_id': '95eee',
#   'propositions': ['The organization aims to build strong community relationships.',
#    'The organization provides service to the community.',
#    'The organization provides service to the school.'],
#   'title': 'Community & Educational Service Initiatives',
#   'summary': "This chunk contains information about the organization's service and engagement initiatives within the community and educational institutions.",
#   'chunk_index': 16},
#  '7f240': {'chunk_id': '7f240',
#   'propositions': ['Social relationships are connections between individuals in a society.',
#    'Social relationships involve interactions among individuals.',
#    'Social relationships can be of different types such as friendships, familial bonds, and professional associations.'],
#   'title': 'Social Relationships Types & Dynamics',
#   'summary': 'This chunk discusses the various types of social relationships and the interactions that define them within a societal context.',
#   'chunk_index': 17},
#  'cf74d': {'chunk_id': 'cf74d',
#   'propositions': ['The organization is committed to scholastic achievement.'],
#   'title': 'Organizational Values in Education',
#   'summary': "This chunk contains information about the organization's values and commitments in education.",
#   'chunk_index': 18},
#  'e8f3c': {'chunk_id': 'e8f3c',
#   'propositions': ['The organization is committed to leadership development.'],
#   'title': 'Organizational Commitments & Initiatives',
#   'summary': "This chunk contains information about the organization's commitments and initiatives.",
#   'chunk_index': 19},
#  '24974': {'chunk_id': '24974',
#   'propositions': ['A list of organizations exists.'],
#   'title': 'Organizations & Details',
#   'summary': 'This chunk contains information about various organizations and their details.',
#   'chunk_index': 20},
#  'd0e0f': {'chunk_id': 'd0e0f',
#   'propositions': ['Alpha Phi Alpha is a fraternity.',
#    'Alpha Phi Alpha is part of NPHC.',
#    "Alpha Phi Alpha has the designation 'Inc.'",
#    'Iota Phi Theta is a fraternity.',
#    'Kappa Alpha Psi is a fraternity.',
#    'Sigma Gamma Rho is a sorority.',
#    "Sigma Gamma Rho has the designation 'Inc.'",
#    'Omega Psi Phi is a fraternity.',
#    'Omega Psi Phi is part of NPHC.',
#    "Omega Psi Phi has the designation 'Inc.'",
#    'Zeta Phi Beta is part of NPHC.',
#    "Zeta Phi Beta has the designation 'Inc.'",
#    "Phi Beta Sigma has the designation 'Inc.'",
#    'Phi Mu Alpha Sinfonia is a fraternity.',
#    "Phi Mu Alpha Sinfonia has the designation 'Inc.'"],
#   'title': 'Greek Letter Organizations & Affiliations',
#   'summary': 'This chunk contains information about Greek letter organizations, their affiliations, and incorporation statuses.',
#   'chunk_index': 21},
#  '3ccd1': {'chunk_id': '3ccd1',
#   'propositions': ['Alpha Kappa Alpha is a sorority.',
#    'Alpha Kappa Alpha is part of NPHC.',
#    "Alpha Kappa Alpha has the designation 'Inc.'",
#    'Iota Phi Theta is part of NPHC.',
#    "Iota Phi Theta has the designation 'Inc.'",
#    'Delta Sigma Theta is a sorority.',
#    'Delta Sigma Theta is part of NPHC.',
#    "Delta Sigma Theta has the designation 'Inc.'",
#    'Kappa Alpha Psi is part of NPHC.',
#    "Kappa Alpha Psi has the designation 'Inc.'",
#    'Sigma Gamma Rho is part of NPHC.',
#    'Zeta Phi Beta is a sorority.',
#    'Phi Beta Sigma is a fraternity.',
#    'Phi Beta Sigma is part of NPHC.',
#    'Kappa Kappa Psi is a fraternity.'],
#   'title': 'Greek Letter Organizations in NPHC & Their Status',
#   'summary': 'This chunk contains information about different Greek letter organizations, including their membership in the National Pan-Hellenic Council (NPHC), their status as sororities or fraternities, and their incorporation status.',
#   'chunk_index': 22},
#  '8c38e': {'chunk_id': '8c38e',
#   'propositions': ['Hours earned in a dual high school GSU undergraduate program can be used for qualifying hours earned.'],
#   'title': 'Dual Enrollment Credit Transfer Policies',
#   'summary': 'This chunk contains information about credit transfer policies for dual high school and university programs.',
#   'chunk_index': 23},
#  'f8c83': {'chunk_id': 'f8c83',
#   'propositions': ['A full-time GSU student is a student who has earned thirty (30) academic credit hours at GSU.',
#    'The academic credit hours earned at GSU by the full-time GSU student are non-remedial.',
#    'A full-time GSU student is officially classified as a sophomore or above at the end of the previous spring semester.',
#    'Has a cumulative grade point average of at least 50.',
#    'Was enrolled full-time at GSU.',
#    'The entity is in good standing academically with the University.'],
#   'title': 'Academic Criteria for Full-Time GSU Students',
#   'summary': 'This chunk details the criteria and academic achievements necessary for a student to be considered a full-time sophomore or higher at GSU.',
#   'chunk_index': 24},
#  'cf2fb': {'chunk_id': 'cf2fb',
#   'propositions': ['Transcripts can only be requested through the Office of Student Clubs and Organizations.',
#    'The purpose of requesting transcripts through the Office of Student Clubs and Organizations is for membership intake.'],
#   'title': 'Transcript Request Procedures & Purposes',
#   'summary': 'This chunk contains information about the specific procedures and purposes for requesting transcripts through the Office of Student Clubs and Organizations at an educational institution.',
#   'chunk_index': 25}}

# %%
type(chunks)
# Out:
# list

# %%
# Save the chunks to a file
with open("chunk_data.json", "w") as f:
    json.dump(chunks, f, indent=4)

# %%
len(chunks)
# Out:
# 17

# %%
chunks[10]
# Out:
# "I encourage you to embrace the principles from Jim Collins' book 'Good to Great' as you begin this academic year. Jim Collins emphasizes the importance of disciplined people. Jim Collins emphasizes the importance of disciplined thought. Jim Collins emphasizes the importance of disciplined action. Jim Collins suggests that greatness is largely a matter of conscious choice. Jim Collins suggests that greatness is largely a matter of discipline."
